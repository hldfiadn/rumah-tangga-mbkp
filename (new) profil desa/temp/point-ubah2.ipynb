# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("data_cleaned_version2.csv")

# %%
df
# Out:
#         ID       Desa    Nama Kepala Keluarga            Pekerjaan  \
# 0    22180     Lolong   Natalia Benga Blolong  Petani atau Nelayan
# 1    22190   Paubokol          Marianus Nurak  Petani atau Nelayan
# 2    22195   Paubokol            Viktor Gelak  Petani atau Nelayan
# 3    22200   Paubokol             Yoseph Kujo  Petani atau Nelayan
# 4    22205   Paubokol    Hendrikus Laran Ujan  Petani atau Nelayan
# ..     ...        ...                     ...                  ...
# 876  24866   Todanara         Longginus Lango  Petani atau Nelayan
# 877  24867   Todanara      Elias Ola Domaking  Petani atau Nelayan
# 878  24869   Todanara  Antonius Yanto Matarau      Karyawan Swasta
# 879  24887  Labalimut             Petrus Asan              lainnya
# 880  24957   Todanara       Hendrikus Kewaman  Petani atau Nelayan
#
#      Pendapatan Bulanan Sumber Listrik Air Bersih  Luas Lahan Usaha m2  \
# 0              200000.0            PLN       PDAM                  0.0
# ...

# %% [markdown]
# ## poin 1 : pendapatan bulanan

# %%
pd.set_option('display.max_rows', 500)

# %%
df['Pendapatan Bulanan'].value_counts().sort_index()
# Out:
# Pendapatan Bulanan
# 0.0            34
# 500.0           1
# 700.0           1
# 15000.0         1
# 33000.0         1
# 50000.0         9
# 75000.0         1
# 80000.0         1
# 100000.0       23
# 150000.0        8
# 160000.0        1
# 166000.0        1
# 200000.0       39
# 230000.0        1
# 250000.0       17
# 300000.0       44
# 350000.0        4
# 358000.0        1
# 395000.0        1
# 400000.0       21
# 450000.0        8
# 475000.0        1
# 500000.0      119
# 540000.0        1
# 570000.0        1
# 600000.0       13
# 601630.0        1
# 620000.0        1
# 630000.0        1
# 700000.0       12
# 720000.0        2
# 750000.0       11
# 800000.0       19
# 833000.0        1
# 848000.0        1
# 850000.0        1
# 875000.0        1
# 900000.0        3
# 925000.0        1
# 933000.0        1
# 1000000.0     118
# 1022330.0       1
# 1050000.0       2
# 1090000.0       1
# 1100000.0       1
# 1175000.0       1
# 1200000.0      10
# 1291000.0       1
# ...

# %%
UMK_NTT = 2328669

# %%
"""persentase_gaji = (
    df.groupby('Desa')['Pendapatan Bulanan']
      .apply(lambda x: (x > UMK_NTT).mean() * 100)
      .reset_index(name='Persentase gaji di atas UMK')
)"""

# %%
rata_rata_gaji = df.groupby('Desa')['Pendapatan Bulanan'].agg([
    ("Rata-rata Penghasilan", 'mean')
]).reset_index()

# %%
# persentase_gaji

# %%
rata_rata_gaji
# Out:
#             Desa  Rata-rata Penghasilan
# 0      Balauring           1.398357e+06
# 1     Benihading           3.638690e+06
# 2           Bour           1.528589e+06
# 3       Dikesare           7.566667e+05
# 4       Duawutun           1.591667e+06
# 5      Dulitukan           1.747400e+06
# 6       Hoelea I           2.566667e+06
# 7      Ile Kimok           1.750000e+06
# 8        Kalikur           2.068333e+06
# 9       Katakeja           2.499032e+06
# 10     Labalimut           1.978333e+06
# 11      Lamatuka           2.627452e+06
# 12    Laranwutun           1.735000e+06
# 13        Lolong           7.800000e+05
# 14         Mahal           8.608333e+05
# 15       Merdeka           2.662500e+06
# 16       Muruona           9.268293e+05
# 17      Nubamado           1.073833e+06
# 18          Pada           1.627419e+06
# 19      Paubokol           5.450000e+05
# 20          Puor           2.828333e+06
# 21      Riangbao           1.546667e+06
# ...

# %%
df_point = rata_rata_gaji[['Desa']].copy()
df_point = df_point.merge(
    rata_rata_gaji[['Desa','Rata-rata Penghasilan']],
    on='Desa', how='left'
)

# %%
df_point
# Out:
#             Desa  Rata-rata Penghasilan
# 0      Balauring           1.398357e+06
# 1     Benihading           3.638690e+06
# 2           Bour           1.528589e+06
# 3       Dikesare           7.566667e+05
# 4       Duawutun           1.591667e+06
# 5      Dulitukan           1.747400e+06
# 6       Hoelea I           2.566667e+06
# 7      Ile Kimok           1.750000e+06
# 8        Kalikur           2.068333e+06
# 9       Katakeja           2.499032e+06
# 10     Labalimut           1.978333e+06
# 11      Lamatuka           2.627452e+06
# 12    Laranwutun           1.735000e+06
# 13        Lolong           7.800000e+05
# 14         Mahal           8.608333e+05
# 15       Merdeka           2.662500e+06
# 16       Muruona           9.268293e+05
# 17      Nubamado           1.073833e+06
# 18          Pada           1.627419e+06
# 19      Paubokol           5.450000e+05
# 20          Puor           2.828333e+06
# 21      Riangbao           1.546667e+06
# ...

# %% [markdown]
# ## Point 2 : Sumber Listrik

# %%
df['Sumber Listrik'].value_counts()
# Out:
# Sumber Listrik
# PLN          871
# Tidak ada      5
# Bukan PLN      5
# Name: count, dtype: int64

# %%
persentase_PLN = (
    df.groupby('Desa')['Sumber Listrik']
      .apply(lambda x: (x == "PLN").mean() * 100)
      .reset_index(name='Persentase sumber listrik PLN')
)

# %%
persentase_PLN
# Out:
#             Desa  Persentase sumber listrik PLN
# 0      Balauring                     100.000000
# 1     Benihading                     100.000000
# 2           Bour                      96.428571
# 3       Dikesare                     100.000000
# 4       Duawutun                     100.000000
# 5      Dulitukan                     100.000000
# 6       Hoelea I                     100.000000
# 7      Ile Kimok                     100.000000
# 8        Kalikur                     100.000000
# 9       Katakeja                      96.774194
# 10     Labalimut                     100.000000
# 11      Lamatuka                     100.000000
# 12    Laranwutun                     100.000000
# 13        Lolong                     100.000000
# 14         Mahal                     100.000000
# 15       Merdeka                     100.000000
# 16       Muruona                     100.000000
# 17      Nubamado                      90.000000
# 18          Pada                      93.548387
# ...

# %%
df_point = df_point.merge(
    persentase_PLN[['Desa','Persentase sumber listrik PLN']],
    on='Desa', how='left'
)

# %%
df_point
# Out:
#             Desa  Rata-rata Penghasilan  Persentase sumber listrik PLN
# 0      Balauring           1.398357e+06                     100.000000
# 1     Benihading           3.638690e+06                     100.000000
# 2           Bour           1.528589e+06                      96.428571
# 3       Dikesare           7.566667e+05                     100.000000
# 4       Duawutun           1.591667e+06                     100.000000
# 5      Dulitukan           1.747400e+06                     100.000000
# 6       Hoelea I           2.566667e+06                     100.000000
# 7      Ile Kimok           1.750000e+06                     100.000000
# 8        Kalikur           2.068333e+06                     100.000000
# 9       Katakeja           2.499032e+06                      96.774194
# 10     Labalimut           1.978333e+06                     100.000000
# 11      Lamatuka           2.627452e+06                     100.000000
# ...

# %% [markdown]
# ## point 3 : Air Bersih

# %%
df['Air Bersih'].value_counts()
# Out:
# Air Bersih
# PDAM          430
# Sumur Bor     143
# Mata Air      112
# Sungai         66
# Air Hujan      64
# Sumur Gali     61
# Air Galon       5
# Name: count, dtype: int64

# %%
persentase_air_PDAM = (
    df.groupby('Desa')['Air Bersih']
      .apply(lambda x: (x == "PDAM").mean() * 100)
      .reset_index(name='Persentase air bersih PDAM')
)

# %%
persentase_air_PDAM
# Out:
#             Desa  Persentase air bersih PDAM
# 0      Balauring                   76.666667
# 1     Benihading                    0.000000
# 2           Bour                    0.000000
# 3       Dikesare                    0.000000
# 4       Duawutun                  100.000000
# 5      Dulitukan                   16.666667
# 6       Hoelea I                    0.000000
# 7      Ile Kimok                    0.000000
# 8        Kalikur                    0.000000
# 9       Katakeja                  100.000000
# 10     Labalimut                  100.000000
# 11      Lamatuka                  100.000000
# 12    Laranwutun                  100.000000
# 13        Lolong                  100.000000
# 14         Mahal                    3.333333
# 15       Merdeka                    0.000000
# 16       Muruona                  100.000000
# 17      Nubamado                  100.000000
# 18          Pada                   93.548387
# 19      Paubokol                    0.000000
# ...

# %%
df_point = df_point.merge(
    persentase_air_PDAM[['Desa','Persentase air bersih PDAM']],
    on='Desa', how='left'
)

# %%
df_point
# Out:
#             Desa  Rata-rata Penghasilan  Persentase sumber listrik PLN  \
# 0      Balauring           1.398357e+06                     100.000000
# 1     Benihading           3.638690e+06                     100.000000
# 2           Bour           1.528589e+06                      96.428571
# 3       Dikesare           7.566667e+05                     100.000000
# 4       Duawutun           1.591667e+06                     100.000000
# 5      Dulitukan           1.747400e+06                     100.000000
# 6       Hoelea I           2.566667e+06                     100.000000
# 7      Ile Kimok           1.750000e+06                     100.000000
# 8        Kalikur           2.068333e+06                     100.000000
# 9       Katakeja           2.499032e+06                      96.774194
# 10     Labalimut           1.978333e+06                     100.000000
# 11      Lamatuka           2.627452e+06                     100.000000
# ...

# %% [markdown]
# ## point 4 : Luas Bangunan Rumah

# %%
df['Luas Bangunan Rumah m2'].value_counts().sort_index()
# Out:
# Luas Bangunan Rumah m2
# 0.000        90
# 18.000        2
# 19.250        1
# 20.000        8
# 21.000        1
# 22.000        1
# 23.000        1
# 24.000       33
# 25.000        3
# 27.000        3
# 28.000        2
# 29.000        1
# 30.000       27
# 31.000        1
# 32.000        2
# 33.000        1
# 34.000        2
# 35.000       96
# 36.000       14
# 37.500        1
# 38.000        1
# 38.500        2
# 39.000        2
# 40.000       11
# 41.250        3
# 42.000       50
# 42.110        1
# 44.000        1
# 45.000       10
# 46.000        1
# 47.000        1
# 48.000       98
# 48.750        2
# 49.000        3
# 49.190        1
# 50.000        9
# 51.000        2
# 52.000        1
# 54.000       43
# 55.000        2
# 56.000       38
# 58.500        1
# 60.000       10
# 62.000        1
# 63.000       48
# 64.000        5
# 64.110        1
# 67.500        2
# 68.000        3
# 70.000        6
# 72.000       19
# 73.410        1
# 74.700        1
# 75.000        3
# ...

# %%
"""persentase_bangunan_rumah = (
    df.groupby('Desa')['Luas Bangunan Rumah m2']
      .apply(lambda x: (x > 36).mean() * 100)
      .reset_index(name='Persentase bangunan rumah bukan "rumah kecil"')
)"""

# %%
rata_rata_luas_rumah = df.groupby('Desa')['Luas Bangunan Rumah m2'].agg([
    ("Rata-rata Luas Bangunan Rumah (m2)", 'mean')
]).reset_index()

# %%
#persentase_bangunan_rumah

# %%
rata_rata_luas_rumah
# Out:
#             Desa  Rata-rata Luas Bangunan Rumah (m2)
# 0      Balauring                           82.933333
# 1     Benihading                           41.400000
# 2           Bour                           62.107143
# 3       Dikesare                           80.666667
# 4       Duawutun                          306.366667
# 5      Dulitukan                           53.933333
# 6       Hoelea I                           59.975000
# 7      Ile Kimok                           59.833333
# 8        Kalikur                           50.100000
# 9       Katakeja                           64.532258
# 10     Labalimut                           44.400000
# 11      Lamatuka                           80.354839
# 12    Laranwutun                           68.600000
# 13        Lolong                           36.300000
# 14         Mahal                           61.366667
# 15       Merdeka                           77.383333
# 16       Muruona                           69.695122
# ...

# %%
df_point = df_point.merge(
    rata_rata_luas_rumah[['Desa','Rata-rata Luas Bangunan Rumah (m2)']],
    on='Desa', how='left'
)

# %%
df_point
# Out:
#             Desa  Rata-rata Penghasilan  Persentase sumber listrik PLN  \
# 0      Balauring           1.398357e+06                     100.000000
# 1     Benihading           3.638690e+06                     100.000000
# 2           Bour           1.528589e+06                      96.428571
# 3       Dikesare           7.566667e+05                     100.000000
# 4       Duawutun           1.591667e+06                     100.000000
# 5      Dulitukan           1.747400e+06                     100.000000
# 6       Hoelea I           2.566667e+06                     100.000000
# 7      Ile Kimok           1.750000e+06                     100.000000
# 8        Kalikur           2.068333e+06                     100.000000
# 9       Katakeja           2.499032e+06                      96.774194
# 10     Labalimut           1.978333e+06                     100.000000
# 11      Lamatuka           2.627452e+06                     100.000000
# ...

# %% [markdown]
# ## Point 5 : Luas Lahan Pertanian

# %%
df['Total_Luas Lahan Pertanian'].value_counts().sort_index()
# Out:
# Total_Luas Lahan Pertanian
# 0.00000       243
# 0.00300         2
# 0.00350         3
# 0.00400         1
# 0.00425         1
# 0.00500         2
# 0.00800         1
# 0.00900         2
# 0.01000         4
# 0.01120         1
# 0.01200         2
# 0.01400         1
# 0.01500         3
# 0.02000         1
# 0.02100         1
# 0.02400         1
# 0.02500         6
# 0.03000         5
# 0.03500         1
# 0.04000         5
# 0.04200         1
# 0.05000        13
# 0.06000         8
# 0.06250         7
# 0.06400         1
# 0.07500         6
# 0.08000         4
# 0.08750         1
# 0.09000         3
# 0.10000         1
# 0.10065         1
# 0.10500         1
# 0.12500         1
# 0.13500         1
# 0.15000         6
# 0.16000         4
# 0.18000         2
# 0.18250         1
# 0.18750         5
# 0.18990         1
# 0.19750         1
# 0.20000         5
# 0.21000         2
# 0.21440         1
# 0.22000         1
# 0.22370         1
# 0.22500         1
# 0.24000         4
# ...

# %%
data_luas_lahan = df.groupby('Desa')['Total_Luas Lahan Pertanian'].agg([
    ("Total seluruh luas lahan (Ha)", 'sum'),
    ("Rata-rata luas lahan (Ha)", 'mean')
]).reset_index()

# %%
data_luas_lahan
# Out:
#             Desa  Total seluruh luas lahan (Ha)  Rata-rata luas lahan (Ha)
# 0      Balauring                       310.5000                  10.350000
# 1     Benihading                        34.6870                   1.156233
# 2           Bour                        20.1635                   0.720125
# 3       Dikesare                         6.1780                   0.205933
# 4       Duawutun                        27.8500                   0.928333
# 5      Dulitukan                        30.7675                   1.025583
# 6       Hoelea I                        14.2750                   0.475833
# 7      Ile Kimok                       718.6950                  23.956500
# 8        Kalikur                       507.9950                  16.933167
# 9       Katakeja                        10.2400                   0.330323
# 10     Labalimut                      4146.9837                 138.232790
# ...

# %%
df_point = df_point.merge(
    data_luas_lahan[['Desa','Total seluruh luas lahan (Ha)']],
    on='Desa', how='left'
)

# %%
df_point
# Out:
#             Desa  Rata-rata Penghasilan  Persentase sumber listrik PLN  \
# 0      Balauring           1.398357e+06                     100.000000
# 1     Benihading           3.638690e+06                     100.000000
# 2           Bour           1.528589e+06                      96.428571
# 3       Dikesare           7.566667e+05                     100.000000
# 4       Duawutun           1.591667e+06                     100.000000
# 5      Dulitukan           1.747400e+06                     100.000000
# 6       Hoelea I           2.566667e+06                     100.000000
# 7      Ile Kimok           1.750000e+06                     100.000000
# 8        Kalikur           2.068333e+06                     100.000000
# 9       Katakeja           2.499032e+06                      96.774194
# 10     Labalimut           1.978333e+06                     100.000000
# 11      Lamatuka           2.627452e+06                     100.000000
# ...

# %% [markdown]
# ## Point 6 : Total Produksi Pertanian

# %%
df['Total_Produksi'].value_counts().sort_index()
# Out:
# Total_Produksi
# 0.000000       284
# 0.001000         3
# 0.001100         1
# 0.002000         1
# 0.002400         1
# 0.003000         1
# 0.004000         2
# 0.005000         5
# 0.007600         1
# 0.010000         1
# 0.012000         1
# 0.015000         3
# 0.016000         1
# 0.016535         2
# 0.020000        12
# 0.022000         1
# 0.022046         3
# 0.025000         3
# 0.030000        14
# 0.031000         2
# 0.040000         2
# 0.050000        14
# 0.055000         3
# 0.055100         1
# 0.055116         2
# 0.060000         9
# 0.062000         1
# 0.065000         3
# 0.070000         1
# 0.070000         5
# 0.075000         6
# 0.077162         1
# 0.077500         1
# 0.080000        10
# 0.081000         1
# 0.084000         1
# 0.085000         2
# 0.090000         5
# 0.100000        22
# 0.105000         1
# 0.108000         1
# 0.110000         6
# 0.111000         1
# 0.115000         1
# 0.120000         6
# 0.122500         1
# ...

# %%
data_produksi = df.groupby('Desa')['Total_Produksi'].agg([
    ("Total seluruh produksi pertanian (ton)", 'sum'),
    ("Rata-rata produksi pertanian (ton)", 'mean')
]).reset_index()

# %%
data_produksi
# Out:
#             Desa  Total seluruh produksi pertanian (ton)  \
# 0      Balauring                               14.900000
# 1     Benihading                               17.788760
# 2           Bour                               59.641000
# 3       Dikesare                              603.813294
# 4       Duawutun                              176.680000
# 5      Dulitukan                               53.071900
# 6       Hoelea I                               19.476000
# 7      Ile Kimok                              216.365000
# 8        Kalikur                              445.190000
# 9       Katakeja                                0.880000
# 10     Labalimut                             1729.677000
# 11      Lamatuka                               14.307300
# 12    Laranwutun                              244.275500
# 13        Lolong                                3.518000
# 14         Mahal                              631.856000
# ...

# %%
df_point = df_point.merge(
    data_produksi[['Desa','Total seluruh produksi pertanian (ton)']],
    on='Desa', how='left'
)

# %%
df_point
# Out:
#             Desa  Rata-rata Penghasilan  Persentase sumber listrik PLN  \
# 0      Balauring           1.398357e+06                     100.000000
# 1     Benihading           3.638690e+06                     100.000000
# 2           Bour           1.528589e+06                      96.428571
# 3       Dikesare           7.566667e+05                     100.000000
# 4       Duawutun           1.591667e+06                     100.000000
# 5      Dulitukan           1.747400e+06                     100.000000
# 6       Hoelea I           2.566667e+06                     100.000000
# 7      Ile Kimok           1.750000e+06                     100.000000
# 8        Kalikur           2.068333e+06                     100.000000
# 9       Katakeja           2.499032e+06                      96.774194
# 10     Labalimut           1.978333e+06                     100.000000
# 11      Lamatuka           2.627452e+06                     100.000000
# ...

# %% [markdown]
# ## Point 7 : Hasil Tangkapan Ikan

# %%
df['Total_Hasil Tangkapan (Kg)'].value_counts().sort_index()
# Out:
# Total_Hasil Tangkapan (Kg)
# 0.0      776
# 1.0       12
# 1.5        1
# 2.0       15
# 2.7        1
# 3.0       13
# 4.0        9
# 5.0       12
# 6.0        2
# 8.0        3
# 10.0      12
# 12.0       1
# 15.0       4
# 20.0      10
# 25.0       1
# 30.0       4
# 40.0       1
# 50.0       1
# 60.0       1
# 90.0       1
# 150.0      1
# Name: count, dtype: int64

# %%
data_perikanan_tangkap = df.groupby('Desa')['Total_Hasil Tangkapan (Kg)'].agg([
    ("Total seluruh tangkapan ikan (Kg)", 'sum'),
    ("Rata-rata tangkapan ikan (Kg)", 'mean')
]).reset_index()

# %%
data_perikanan_tangkap
# Out:
#             Desa  Total seluruh tangkapan ikan (Kg)  \
# 0      Balauring                              279.0
# 1     Benihading                                0.0
# 2           Bour                               23.0
# 3       Dikesare                              230.0
# 4       Duawutun                               37.0
# 5      Dulitukan                                9.0
# 6       Hoelea I                               13.0
# 7      Ile Kimok                                0.0
# 8        Kalikur                               82.0
# 9       Katakeja                                0.0
# 10     Labalimut                                0.0
# 11      Lamatuka                               78.0
# 12    Laranwutun                               68.0
# 13        Lolong                               11.0
# 14         Mahal                                3.0
# 15       Merdeka                                6.5
# 16       Muruona                               50.0
# ...

# %%
df_point = df_point.merge(
    data_perikanan_tangkap[['Desa','Total seluruh tangkapan ikan (Kg)']],
    on='Desa', how='left'
)

# %%
df_point
# Out:
#             Desa  Rata-rata Penghasilan  Persentase sumber listrik PLN  \
# 0      Balauring           1.398357e+06                     100.000000
# 1     Benihading           3.638690e+06                     100.000000
# 2           Bour           1.528589e+06                      96.428571
# 3       Dikesare           7.566667e+05                     100.000000
# 4       Duawutun           1.591667e+06                     100.000000
# 5      Dulitukan           1.747400e+06                     100.000000
# 6       Hoelea I           2.566667e+06                     100.000000
# 7      Ile Kimok           1.750000e+06                     100.000000
# 8        Kalikur           2.068333e+06                     100.000000
# 9       Katakeja           2.499032e+06                      96.774194
# 10     Labalimut           1.978333e+06                     100.000000
# 11      Lamatuka           2.627452e+06                     100.000000
# ...

# %% [markdown]
# ## Point 8 : Pembelian Pupuk

# %%
df_petani = df[df['Pekerjaan'] == 'Petani atau Nelayan'].copy()

# %%
df_petani['Total_Luas Lahan Pertanian'].value_counts().sort_index()
# Out:
# Total_Luas Lahan Pertanian
# 0.00000       99
# 0.00300        2
# 0.00350        2
# 0.00425        1
# 0.00500        1
# 0.00800        1
# 0.00900        1
# 0.01000        3
# 0.01200        2
# 0.01400        1
# 0.01500        1
# 0.02000        1
# 0.02100        1
# 0.02400        1
# 0.02500        4
# 0.03000        4
# 0.04000        3
# 0.04200        1
# 0.05000        9
# 0.06000        4
# 0.06250        4
# 0.07500        4
# 0.08000        2
# 0.09000        2
# 0.10065        1
# 0.13500        1
# 0.15000        2
# 0.16000        4
# 0.18000        1
# 0.18250        1
# 0.18750        4
# 0.18990        1
# 0.19750        1
# 0.20000        4
# 0.21000        2
# 0.21440        1
# 0.22000        1
# 0.22370        1
# 0.22500        1
# 0.24000        2
# 0.25000       22
# 0.27500        1
# 0.28000        1
# 0.30000        6
# 0.31250        1
# 0.32000        1
# 0.37500        3
# 0.40000        3
# 0.45000        1
# 0.45000        2
# 0.48000        1
# ...

# %%
df_petani = df_petani[df_petani['Total_Luas Lahan Pertanian'] != 0.0000].copy()

# %%
df_petani['Desa'].value_counts()
# Out:
# Desa
# Ile Kimok       28
# Benihading      27
# Dulitukan       23
# Muruona         23
# Tagawiti        22
# Paubokol        21
# Todanara        20
# Lolong          20
# Tubungwalang    19
# Puor            16
# Mahal           16
# Waienga         15
# Lamatuka        15
# Dikesare        14
# Laranwutun      14
# Wuakerong       14
# Merdeka         14
# Nubamado        13
# Labalimut       13
# Bour            12
# Watodiri        12
# Pada            12
# Riangbao        11
# Duawutun        10
# Kalikur          9
# Balauring        9
# Hoelea I         7
# Tubuk Rajan      6
# Katakeja         3
# Name: count, dtype: int64

# %%
df_petani['Pembelian Pupuk'].value_counts().sort_index()
# Out:
# Pembelian Pupuk
# 0.0          376
# 11000.0        1
# 12500.0        1
# 15000.0        1
# 16750.0        1
# 20000.0        1
# 25000.0        2
# 40000.0        1
# 50000.0        7
# 67500.0        1
# 70000.0        1
# 75000.0        1
# 100000.0       1
# 105000.0       1
# 112000.0       1
# 112500.0       1
# 130000.0       1
# 140000.0       1
# 150000.0      22
# 250000.0       1
# 260000.0       1
# 300000.0       5
# 500000.0       1
# 600000.0       1
# 750000.0       1
# 1200000.0      1
# 1500000.0      1
# 1800000.0      3
# 2550000.0      1
# Name: count, dtype: int64

# %%
persentase_pembelian_pupuk = (
    df_petani.groupby('Desa')['Pembelian Pupuk']
      .apply(lambda x: (x > 0).mean() * 100)
      .reset_index(name='Persentase petani membeli pupuk')
)

# %%
persentase_pembelian_pupuk
# Out:
#             Desa  Persentase petani membeli pupuk
# 0      Balauring                        66.666667
# 1     Benihading                         0.000000
# 2           Bour                        50.000000
# 3       Dikesare                         0.000000
# 4       Duawutun                         0.000000
# 5      Dulitukan                         0.000000
# 6       Hoelea I                        85.714286
# 7      Ile Kimok                         7.142857
# 8        Kalikur                       100.000000
# 9       Katakeja                         0.000000
# 10     Labalimut                         0.000000
# 11      Lamatuka                         0.000000
# 12    Laranwutun                         0.000000
# 13        Lolong                         0.000000
# 14         Mahal                        68.750000
# 15       Merdeka                         7.142857
# 16       Muruona                         4.347826
# 17      Nubamado                         0.000000
# ...

# %%
df_point = df_point.merge(
    persentase_pembelian_pupuk[['Desa','Persentase petani membeli pupuk']],
    on='Desa', how='left'
)

# %%
df_point
# Out:
#             Desa  Rata-rata Penghasilan  Persentase sumber listrik PLN  \
# 0      Balauring           1.398357e+06                     100.000000
# 1     Benihading           3.638690e+06                     100.000000
# 2           Bour           1.528589e+06                      96.428571
# 3       Dikesare           7.566667e+05                     100.000000
# 4       Duawutun           1.591667e+06                     100.000000
# 5      Dulitukan           1.747400e+06                     100.000000
# 6       Hoelea I           2.566667e+06                     100.000000
# 7      Ile Kimok           1.750000e+06                     100.000000
# 8        Kalikur           2.068333e+06                     100.000000
# 9       Katakeja           2.499032e+06                      96.774194
# 10     Labalimut           1.978333e+06                     100.000000
# 11      Lamatuka           2.627452e+06                     100.000000
# ...

# %% [markdown]
# ## Point 9 : Pembelian Pestisida

# %%
df_petani['Pembelian Pestisida'].value_counts().sort_index()
# Out:
# Pembelian Pestisida
# 0.0          308
# 6250.0         1
# 7500.0         1
# 10000.0        1
# 14000.0        1
# 25000.0        1
# 30000.0        2
# 35000.0        2
# 40000.0        2
# 50000.0        5
# 56000.0        1
# 58000.0        1
# 70000.0        1
# 75000.0        2
# 80000.0       12
# 85000.0        4
# 90000.0        5
# 100000.0      10
# 110000.0       3
# 115000.0       3
# 120000.0      13
# 125000.0       1
# 130000.0       4
# 135000.0       5
# 140000.0       1
# 150000.0       2
# 160000.0       2
# 180000.0       2
# 200000.0       3
# 240000.0       5
# 255000.0       1
# 270000.0       4
# 300000.0       3
# 350000.0       1
# 360000.0       4
# 390000.0       2
# 400000.0       1
# 405000.0       1
# 480000.0       2
# 500000.0       2
# 510000.0       1
# 540000.0       1
# 600000.0       1
# 620000.0       1
# 720000.0       1
# 800000.0       1
# 805000.0       1
# 900000.0       1
# 1200000.0      1
# 1380000.0      1
# 1500000.0      1
# ...

# %%
persentase_pembelian_pestisida = (
    df_petani.groupby('Desa')['Pembelian Pestisida']
      .apply(lambda x: (x > 0).mean() * 100)
      .reset_index(name='Persentase petani membeli pestisida')
)

# %%
persentase_pembelian_pestisida
# Out:
#             Desa  Persentase petani membeli pestisida
# 0      Balauring                            11.111111
# 1     Benihading                             7.407407
# 2           Bour                            83.333333
# 3       Dikesare                             0.000000
# 4       Duawutun                             0.000000
# 5      Dulitukan                             0.000000
# 6       Hoelea I                            57.142857
# 7      Ile Kimok                            53.571429
# 8        Kalikur                           100.000000
# 9       Katakeja                            33.333333
# 10     Labalimut                             0.000000
# 11      Lamatuka                             0.000000
# 12    Laranwutun                            57.142857
# 13        Lolong                             0.000000
# 14         Mahal                            87.500000
# 15       Merdeka                            28.571429
# ...

# %%
df_point = df_point.merge(
    persentase_pembelian_pestisida[['Desa','Persentase petani membeli pestisida']],
    on='Desa', how='left'
)

# %%
df_point
# Out:
#             Desa  Rata-rata Penghasilan  Persentase sumber listrik PLN  \
# 0      Balauring           1.398357e+06                     100.000000
# 1     Benihading           3.638690e+06                     100.000000
# 2           Bour           1.528589e+06                      96.428571
# 3       Dikesare           7.566667e+05                     100.000000
# 4       Duawutun           1.591667e+06                     100.000000
# 5      Dulitukan           1.747400e+06                     100.000000
# 6       Hoelea I           2.566667e+06                     100.000000
# 7      Ile Kimok           1.750000e+06                     100.000000
# 8        Kalikur           2.068333e+06                     100.000000
# 9       Katakeja           2.499032e+06                      96.774194
# 10     Labalimut           1.978333e+06                     100.000000
# 11      Lamatuka           2.627452e+06                     100.000000
# ...

# %% [markdown]
# ## Point 10 : Sewa Alat Pertanian

# %%
df_petani['Sewa Alat dan Mesin Pertanian'].value_counts().sort_index()
# Out:
# Sewa Alat dan Mesin Pertanian
# 0.0          415
# 20000.0        1
# 40000.0        2
# 50000.0        1
# 100000.0       5
# 120000.0       1
# 125000.0       1
# 150000.0       1
# 250000.0       1
# 400000.0       3
# 480000.0       1
# 500000.0       2
# 580000.0       1
# 600000.0       1
# 1000000.0      2
# Name: count, dtype: int64

# %%
persentase_sewa_alat_pertanian = (
    df_petani.groupby('Desa')['Sewa Alat dan Mesin Pertanian']
      .apply(lambda x: (x > 0).mean() * 100)
      .reset_index(name='Persentase petani menyewa alat pertanian')
)

# %%
persentase_sewa_alat_pertanian
# Out:
#             Desa  Persentase petani menyewa alat pertanian
# 0      Balauring                                  0.000000
# 1     Benihading                                  0.000000
# 2           Bour                                 41.666667
# 3       Dikesare                                  0.000000
# 4       Duawutun                                  0.000000
# 5      Dulitukan                                  0.000000
# 6       Hoelea I                                  0.000000
# 7      Ile Kimok                                  0.000000
# 8        Kalikur                                 11.111111
# 9       Katakeja                                 66.666667
# 10     Labalimut                                  7.692308
# 11      Lamatuka                                  0.000000
# 12    Laranwutun                                  7.142857
# 13        Lolong                                  0.000000
# 14         Mahal                                 12.500000
# ...

# %%
df_point = df_point.merge(
    persentase_sewa_alat_pertanian[['Desa','Persentase petani menyewa alat pertanian']],
    on='Desa', how='left'
)

# %%
df_point
# Out:
#             Desa  Rata-rata Penghasilan  Persentase sumber listrik PLN  \
# 0      Balauring           1.398357e+06                     100.000000
# 1     Benihading           3.638690e+06                     100.000000
# 2           Bour           1.528589e+06                      96.428571
# 3       Dikesare           7.566667e+05                     100.000000
# 4       Duawutun           1.591667e+06                     100.000000
# 5      Dulitukan           1.747400e+06                     100.000000
# 6       Hoelea I           2.566667e+06                     100.000000
# 7      Ile Kimok           1.750000e+06                     100.000000
# 8        Kalikur           2.068333e+06                     100.000000
# 9       Katakeja           2.499032e+06                      96.774194
# 10     Labalimut           1.978333e+06                     100.000000
# 11      Lamatuka           2.627452e+06                     100.000000
# ...

# %% [markdown]
# ## Point 11 : kepemilikan Ternak

# %%
df['jumlah ternak'].value_counts().sort_index()
# Out:
# jumlah ternak
# 0.0      208
# 1.0       50
# 2.0       53
# 3.0       47
# 4.0       55
# 5.0       39
# 6.0       32
# 7.0       43
# 8.0       38
# 9.0       30
# 10.0      36
# 11.0      23
# 12.0      30
# 13.0      21
# 14.0      20
# 15.0      20
# 16.0      11
# 17.0      10
# 18.0       9
# 19.0       9
# 20.0      13
# 21.0       4
# 22.0       8
# 23.0       8
# 24.0       6
# 25.0       4
# 26.0       2
# 27.0       5
# 28.0       4
# 29.0       3
# 30.0       2
# 31.0       3
# 32.0       1
# 33.0       3
# 34.0       3
# 35.0       2
# 36.0       1
# 37.0       1
# 40.0       2
# 41.0       1
# 43.0       1
# 44.0       1
# 45.0       1
# 47.0       1
# 48.0       1
# 50.0       2
# 51.0       1
# 52.0       1
# 55.0       1
# 60.0       2
# 61.0       1
# 70.0       1
# 80.0       1
# 84.0       1
# 96.0       1
# 101.0      1
# 103.0      1
# 124.0      1
# 350.0      1
# Name: count, dtype: int64

# %%
"""persentase_kepemilikan_ternak = (
    df.groupby('Desa')['jumlah ternak']
      .apply(lambda x: (x > 0).mean() * 100)
      .reset_index(name='Persentase kepemilikan ternak')
)"""

# %%
jumlah_ternak = df.groupby('Desa')['jumlah ternak'].agg([
    ("Total jumlah ternak", 'sum'),
    ("Rata-rata jumlah ternak", 'mean')
]).reset_index()

# %%
#persentase_kepemilikan_ternak

# %%
jumlah_ternak
# Out:
#             Desa  Total jumlah ternak  Rata-rata jumlah ternak
# 0      Balauring                233.0                 7.766667
# 1     Benihading                380.0                12.666667
# 2           Bour                273.0                 9.750000
# 3       Dikesare                174.0                 5.800000
# 4       Duawutun                306.0                10.200000
# 5      Dulitukan                435.0                14.500000
# 6       Hoelea I                212.0                 7.066667
# 7      Ile Kimok                518.0                17.266667
# 8        Kalikur                164.0                 5.466667
# 9       Katakeja                309.0                 9.967742
# 10     Labalimut                130.0                 4.333333
# 11      Lamatuka                240.0                 7.741935
# 12    Laranwutun                352.0                11.733333
# 13        Lolong                160.0                 5.333333
# ...

# %%
df_point = df_point.merge(
    jumlah_ternak[['Desa','Total jumlah ternak']],
    on='Desa', how='left'
)

# %%
df_point
# Out:
#             Desa  Rata-rata Penghasilan  Persentase sumber listrik PLN  \
# 0      Balauring           1.398357e+06                     100.000000
# 1     Benihading           3.638690e+06                     100.000000
# 2           Bour           1.528589e+06                      96.428571
# 3       Dikesare           7.566667e+05                     100.000000
# 4       Duawutun           1.591667e+06                     100.000000
# 5      Dulitukan           1.747400e+06                     100.000000
# 6       Hoelea I           2.566667e+06                     100.000000
# 7      Ile Kimok           1.750000e+06                     100.000000
# 8        Kalikur           2.068333e+06                     100.000000
# 9       Katakeja           2.499032e+06                      96.774194
# 10     Labalimut           1.978333e+06                     100.000000
# 11      Lamatuka           2.627452e+06                     100.000000
# ...

# %% [markdown]
# ## Point 12 : Pembelian Obat

# %%
df['Pembelian Obat'].value_counts().sort_index()
# Out:
# Pembelian Obat
# 0.0          739
# 4000.0         1
# 5000.0         8
# 5900.0         1
# 10000.0       34
# 12000.0        1
# 13500.0        1
# 15000.0        6
# 20000.0       12
# 25000.0        8
# 30000.0        7
# 40000.0        1
# 50000.0       10
# 51000.0        1
# 60000.0        3
# 72000.0        1
# 75000.0        2
# 80000.0        1
# 96000.0        1
# 100000.0      13
# 120000.0       8
# 150000.0       4
# 160000.0       1
# 200000.0       5
# 216000.0       1
# 240000.0       4
# 250000.0       2
# 600000.0       1
# 1000000.0      1
# 1200000.0      1
# 2000000.0      1
# 3000000.0      1
# Name: count, dtype: int64

# %%
"""persentase_pembelian_obat = (
    df.groupby('Desa')['Pembelian Obat']
      .apply(lambda x: (x > 0).mean() * 100)
      .reset_index(name='Persentase pembelian obat')
)"""

# %%
rata_rata_pembelian_obat = df.groupby('Desa')['Total_Produksi'].agg([
    ("Rata-rata pembelian obat", 'mean')
]).reset_index()

# %%
#persentase_pembelian_obat

# %%
rata_rata_pembelian_obat
# Out:
#             Desa  Rata-rata pembelian obat
# 0      Balauring                  0.496667
# 1     Benihading                  0.592959
# 2           Bour                  2.130036
# 3       Dikesare                 20.127110
# 4       Duawutun                  5.889333
# 5      Dulitukan                  1.769063
# 6       Hoelea I                  0.649200
# 7      Ile Kimok                  7.212167
# 8        Kalikur                 14.839667
# 9       Katakeja                  0.028387
# 10     Labalimut                 57.655900
# 11      Lamatuka                  0.461526
# 12    Laranwutun                  8.142517
# 13        Lolong                  0.117267
# 14         Mahal                 21.061867
# 15       Merdeka                  0.366567
# 16       Muruona                  2.650610
# 17      Nubamado                 26.615900
# 18          Pada                  0.528710
# 19      Paubokol                  0.714333
# 20          Puor                  0.450300
# ...

# %%
df_point = df_point.merge(
    persentase_pembelian_obat[['Desa','Persentase pembelian obat']],
    on='Desa', how='left'
)

# %%
df_point
# Out:
#             Desa  Rata-rata Penghasilan  Persentase sumber listrik PLN  \
# 0      Balauring           1.398357e+06                     100.000000
# 1     Benihading           3.638690e+06                     100.000000
# 2           Bour           1.528589e+06                      96.428571
# 3       Dikesare           7.566667e+05                     100.000000
# 4       Duawutun           1.591667e+06                     100.000000
# 5      Dulitukan           1.747400e+06                     100.000000
# 6       Hoelea I           2.566667e+06                     100.000000
# 7      Ile Kimok           1.750000e+06                     100.000000
# 8        Kalikur           2.068333e+06                     100.000000
# 9       Katakeja           2.499032e+06                      96.774194
# 10     Labalimut           1.978333e+06                     100.000000
# 11      Lamatuka           2.627452e+06                     100.000000
# ...

# %% [markdown]
# ## Point 13 : Pemeriksaan Balita ke Posyandu

# %%
df_balita = df[df['Balita diperiksa di Posyandu'] != 'Tidak ada'].copy()

# %%
df_balita['Balita diperiksa di Posyandu'].value_counts()
# Out:
# Balita diperiksa di Posyandu
# Sering          266
# Tidak Pernah     15
# Kadang            4
# Name: count, dtype: int64

# %%
persentase_balita_posyandu = (
    df_balita.groupby('Desa')['Balita diperiksa di Posyandu']
      .apply(lambda x: (x == "Sering").mean() * 100)
      .reset_index(name='Persentase balita sering diperiksa di Posyandu')
)

# %%
persentase_balita_posyandu
# Out:
#             Desa  Persentase balita sering diperiksa di Posyandu
# 0      Balauring                                      100.000000
# 1     Benihading                                      100.000000
# 2           Bour                                      100.000000
# 3       Dikesare                                       95.454545
# 4       Duawutun                                      100.000000
# 5      Dulitukan                                      100.000000
# 6       Hoelea I                                       83.333333
# 7      Ile Kimok                                       83.333333
# 8        Kalikur                                       83.333333
# 9       Katakeja                                       50.000000
# 10     Labalimut                                      100.000000
# 11      Lamatuka                                      100.000000
# 12    Laranwutun                                       77.272727
# ...

# %%
df_point = df_point.merge(
    persentase_balita_posyandu[['Desa','Persentase balita sering diperiksa di Posyandu']],
    on='Desa', how='left'
)

# %%
df_point
# Out:
#             Desa  Rata-rata Penghasilan  Persentase sumber listrik PLN  \
# 0      Balauring           1.398357e+06                     100.000000
# 1     Benihading           3.638690e+06                     100.000000
# 2           Bour           1.528589e+06                      96.428571
# 3       Dikesare           7.566667e+05                     100.000000
# 4       Duawutun           1.591667e+06                     100.000000
# 5      Dulitukan           1.747400e+06                     100.000000
# 6       Hoelea I           2.566667e+06                     100.000000
# 7      Ile Kimok           1.750000e+06                     100.000000
# 8        Kalikur           2.068333e+06                     100.000000
# 9       Katakeja           2.499032e+06                      96.774194
# 10     Labalimut           1.978333e+06                     100.000000
# 11      Lamatuka           2.627452e+06                     100.000000
# ...

# %% [markdown]
# ## Point 14 : Terdapat Keluarga yang sering sakit

# %%
df['Anggota keluarga yang sering sakit'].value_counts()
# Out:
# Anggota keluarga yang sering sakit
# Tidak ada    488
# Istri        125
# Suami         98
# Anak          65
# Famili        53
# Orang Tua     52
# Name: count, dtype: int64

# %%
persentase_keluarga_sering_sakit = (
    df.groupby('Desa')['Anggota keluarga yang sering sakit']
      .apply(lambda x: (x != "Tidak ada").mean() * 100)
      .reset_index(name='Persentase terdapat anggota keluarga yang sering sakit')
)

# %%
persentase_keluarga_sering_sakit
# Out:
#             Desa  Persentase terdapat anggota keluarga yang sering sakit
# 0      Balauring                                          33.333333
# 1     Benihading                                          63.333333
# 2           Bour                                          35.714286
# 3       Dikesare                                          20.000000
# 4       Duawutun                                          10.000000
# 5      Dulitukan                                          36.666667
# 6       Hoelea I                                          30.000000
# 7      Ile Kimok                                          86.666667
# 8        Kalikur                                          16.666667
# 9       Katakeja                                          38.709677
# 10     Labalimut                                          73.333333
# 11      Lamatuka                                          54.838710
# 12    Laranwutun                                          60.000000
# ...

# %%
df_point = df_point.merge(
    persentase_keluarga_sering_sakit[['Desa','Persentase terdapat anggota keluarga yang sering sakit']],
    on='Desa', how='left'
)

# %%
df_point
# Out:
#             Desa  Rata-rata Penghasilan  Persentase sumber listrik PLN  \
# 0      Balauring           1.398357e+06                     100.000000
# 1     Benihading           3.638690e+06                     100.000000
# 2           Bour           1.528589e+06                      96.428571
# 3       Dikesare           7.566667e+05                     100.000000
# 4       Duawutun           1.591667e+06                     100.000000
# 5      Dulitukan           1.747400e+06                     100.000000
# 6       Hoelea I           2.566667e+06                     100.000000
# 7      Ile Kimok           1.750000e+06                     100.000000
# 8        Kalikur           2.068333e+06                     100.000000
# 9       Katakeja           2.499032e+06                      96.774194
# 10     Labalimut           1.978333e+06                     100.000000
# 11      Lamatuka           2.627452e+06                     100.000000
# ...

# %% [markdown]
# ## Point 15 : Bantuan Pemerintah

# %%
df['Pernah dapat bantuan dari pemerintah'].value_counts()
# Out:
# Pernah dapat bantuan dari pemerintah
# Pernah    563
# Tidak     318
# Name: count, dtype: int64

# %%
persentase_bantuan_pemerintah = (
    df.groupby('Desa')['Pernah dapat bantuan dari pemerintah']
      .apply(lambda x: (x == "Pernah").mean() * 100)
      .reset_index(name='Persentase mendapat bantuan dari pemerintah')
)

# %%
persentase_bantuan_pemerintah
# Out:
#             Desa  Persentase mendapat bantuan dari pemerintah
# 0      Balauring                                    70.000000
# 1     Benihading                                    83.333333
# 2           Bour                                    85.714286
# 3       Dikesare                                    76.666667
# 4       Duawutun                                    50.000000
# 5      Dulitukan                                    63.333333
# 6       Hoelea I                                    86.666667
# 7      Ile Kimok                                    80.000000
# 8        Kalikur                                    46.666667
# 9       Katakeja                                    61.290323
# 10     Labalimut                                    70.000000
# 11      Lamatuka                                    61.290323
# 12    Laranwutun                                    60.000000
# 13        Lolong                                    80.000000
# ...

# %%
df_point = df_point.merge(
    persentase_bantuan_pemerintah[['Desa','Persentase mendapat bantuan dari pemerintah']],
    on='Desa', how='left'
)

# %%
df_point
# Out:
#             Desa  Rata-rata Penghasilan  Persentase sumber listrik PLN  \
# 0      Balauring           1.398357e+06                     100.000000
# 1     Benihading           3.638690e+06                     100.000000
# 2           Bour           1.528589e+06                      96.428571
# 3       Dikesare           7.566667e+05                     100.000000
# 4       Duawutun           1.591667e+06                     100.000000
# 5      Dulitukan           1.747400e+06                     100.000000
# 6       Hoelea I           2.566667e+06                     100.000000
# 7      Ile Kimok           1.750000e+06                     100.000000
# 8        Kalikur           2.068333e+06                     100.000000
# 9       Katakeja           2.499032e+06                      96.774194
# 10     Labalimut           1.978333e+06                     100.000000
# 11      Lamatuka           2.627452e+06                     100.000000
# ...

# %% [markdown]
# # Save dataset

# %%
df_point.to_csv("data_skor_per_desa.csv", index=False)
