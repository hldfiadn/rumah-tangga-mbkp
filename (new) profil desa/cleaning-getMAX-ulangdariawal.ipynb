# %%
import re
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data_rumah_tangga_all.csv")

# %%
df.head()
# Out:
#    #     ID   Nama Kepala Keluarga  Nomor Kartu Keluarga    Tanggal Pendataan  \
# 0  1  22180  Natalia Benga Blolong          5.313011e+15  2024-09-23 00:00:00
# 1  2  22190         Marianus Nurak          5.313052e+15  2024-10-07 00:00:00
# 2  3  22195           Viktor Gelak          5.313052e+15  2024-10-07 00:00:00
# 3  4  22200            Yoseph Kujo          5.313051e+15  2024-10-08 00:00:00
# 4  5  22205   Hendrikus Laran Ujan          5.313052e+15  2024-10-08 00:00:00
#
#        Dusun Desa/Kelurahan   Kecamatan Kabupaten             Propinsi  ...  \
# 0  A Arubala         Lolong  Nagawutung   Lembata  Nusa Tenggara Timur  ...
# 1   Alapnimo       Paubokol   Nubatukan   Lembata  Nusa Tenggara Timur  ...
# 2   Alapnimo       Paubokol   Nubatukan   Lembata  Nusa Tenggara Timur  ...
# 3   Alapnimo       Paubokol   Nubatukan   Lembata  Nusa Tenggara Timur  ...
# 4   Alapnimo       Paubokol   Nubatukan   Lembata  Nusa Tenggara Timur  ...
#
#   Apakah pernah dapat bantuan dari pemerintah?  \
# 0                                      Pernah;
# 1                                      Pernah;
# 2                                      Pernah;
# 3                                      Pernah;
# 4                                      Pernah;
#
#   Kalau iya, apa bentuk bantuan tersebut?  \
# 0                                  Tunai;
# 1                                  Tunai;
# 2                                  Tunai;
# 3                                  Tunai;
# 4                                  Tunai;
#
#   Jumlah difabel (berkebutuhan khusus) Jenis Difabel  \
# 0                                   0;    Tidak ada;
# 1                                   0;    Tidak ada;
# 2                                   0;    Tidak ada;
# 3                                   0;    Tidak ada;
# 4                                   0;    Tidak ada;
#
#   Memiliki anak usia kurang dari 5 tahun Tinggi badan anak Berat badan anak  \
# 0                             Tidak ada;                0;               0;
# 1                                   Ada;               76;             8,7;
# 2                             Tidak ada;                0;               0;
# 3                                   Ada;               97;            15,2;
# 4                                   Ada;               86;              10;
#
#   Apakah anak mengalami kasus gizi buruk?  \
# 0                              Tidak ada;
# 1                              Tidak ada;
# 2                              Tidak ada;
# 3                                  Tidak;
# 4                              Tidak ada;
#
#   Apakah anak mengalami kekurangan gizi?  SourceFile
# 0                             Tidak ada;  1-400.xlsx
# 1                             Tidak ada;  1-400.xlsx
# 2                             Tidak ada;  1-400.xlsx
# 3                                 Tidak;  1-400.xlsx
# 4                                    Ya;  1-400.xlsx
#
# [5 rows x 269 columns]

# %%
df['Desa/Kelurahan'] = df['Desa/Kelurahan'].str.replace(r'\bPADA\b', 'Pada', regex=True)

# %%
for i, col in enumerate(df.columns):
    print(f"{i}. {col}")
# Out:
# 0. #
# 1. ID
# 2. Nama Kepala Keluarga
# 3. Nomor Kartu Keluarga
# 4. Tanggal Pendataan
# 5. Dusun
# 6. Desa/Kelurahan
# 7. Kecamatan
# 8. Kabupaten
# 9. Propinsi
# 10. Koordinat GPS
# 11. Sumber Listrik
# 12. Air Bersih
# 13. Kepemilikan Rumah
# 14. Nama
# 15. Jumlah Anggota Keluarga (jiwa)
# 16. Agama/ Kepercayaan
# 17. Pekerjaan
# 18. Pendapatan Bulanan (Rp.)
# 19. Beras Lokal (Sawah/Ladang dalam Kg)
# 20. Singkong
# 21. Jagung Lokal
# 22. Jagung Hibrida
# 23. Umbi-umbian lain
# 24. Sorgum
# 25. Jewawut/Weteng
# 26. Ikan dan Boga Laut Segar
# 27. Ikan dan Boga Laut Kering
# 28. Telor
# 29. Ayam
# 30. Daging (Sapi/Kerbau/Kambing/Babi,dll)
# 31. Kacang-kacangan
# 32. Minyak Kelapa
# 33. Cabai Besar
# 34. Cabai Kecil
# 35. Kemiri
# 36. Kunyit
# 37. Jahe
# 38. Sereh
# 39. Lengkuas
# 40. Jeruk Nipis
# 41. Mete
# 42. Lain-lain
# 43. Beras Lokal (Sawah/Ladang)
# 44. Singkong.1
# 45. Jagung Lokal.1
# 46. Jagung Hibrida.1
# 47. Umbi-umbian lain.1
# 48. Sorgum.1
# 49. Jewawut/Weteng.1
# 50. Ikan dan Boga Laut Segar.1
# 51. Ikan dan Boga Laut Kering.1
# 52. Telor.1
# 53. Ayam.1
# 54. Kacang-kacangan.1
# 55. Minyak Kelapa.1
# 56. Cabai Besar.1
# 57. Cabai Kecil.1
# 58. Kemiri.1
# 59. Kunyit.1
# 60. Jahe.1
# 61. Sereh.1
# 62. Lengkuas.1
# 63. Jeruk Nipis.1
# 64. Mete.1
# 65. Lain-lain.1
# 66. Beras Lokal (Sawah/Ladang dalam Rp)
# 67. Beras Toko
# 68. Singkong.2
# 69. Jagung Lokal.2
# 70. Jagung Hibrida.2
# 71. Umbi-umbian lain.2
# 72. Sorgum.2
# 73. Jewawut/Weteng.2
# 74. Ikan dan Boga Laut Segar.2
# 75. Ikan dan Boga Laut Kering.2
# 76. Telor.2
# 77. Ayam.2
# 78. Daging (Sapi/Kerbau/Kambing/Babi,dll).1
# 79. Tahu dan Tempe
# 80. Kacang-kacangan.2
# 81. Daun Ubi
# 82. Kangkung
# 83. Kubis
# 84. Sawi
# 85. Bayam
# 86. Brokoli
# 87. Wortel
# 88. Jantung Pisang
# 89. Kelor
# 90. Bunga dan Daun Pepaya
# 91. Pakis/Paku
# 92. Rebung
# 93. Mangga
# 94. Alpukat
# 95. Jeruk
# 96. Anggur
# 97. Buah Naga
# 98. Mete.2
# 99. Pisang
# 100. Rambutan
# 101. Nanas
# 102. Salak
# 103. Pepaya
# 104. Kelapa
# 105. Tomat
# 106. Timun
# 107. Labu
# 108. Kemangi
# 109. Minyak Kelapa.2
# 110. Minyak Goreng Kemasan/Toko
# 111. Bumbu Kemasan
# 112. MSG
# 113. Bawang Merah
# 114. Bawang Putih
# 115. Bawang Bombai
# 116. Cabai Besar.2
# 117. Cabai Kecil.2
# 118. Lada
# 119. Kemiri.2
# 120. Kunyit.2
# 121. Jahe.2
# 122. Sereh.2
# 123. Lengkuas.2
# 124. Jeruk Nipis.2
# 125. Jeruk Limau
# 126. Kecap
# 127. Saos
# 128. Susu (Bubuk/UHT)
# 129. Kental Manis
# 130. Minuman Kemasan
# 131. Minuman Fermentasi
# 132. Gula Pasir
# 133. Kopi
# 134. Teh
# 135. Mie Instan
# 136. Biskuit/Roti/Kue Kemasan
# 137. Rokok Kemasan
# 138. Tembakau
# 139. Pinang
# 140. Daun Sirih
# 141. Minyak Tanah
# 142. Gas
# 143. Biaya Listrik
# 144. BBM
# 145. Pupuk
# 146. Pestisida/Herbisida/Fungisida
# 147. Benih
# 148. Upah Buruh
# 149. Sewa Alat dan Mesin Pertanian
# 150. Transportasi
# 151. SPP (Iuran Sekolah)
# 152. Peralatan Sekolah/ATK
# 153. Transportasi/Kos/Jajan
# 154. Periksa Kesehatan
# 155. Iuran BPJS
# 156. Obat
# 157. Sanitary
# 158. Pulsa Ponsel
# 159. Dana Sosial (Arisan, Sumbangan, dll)
# 160. Nama Tanaman
# 161. Jenis Pangan
# 162. Varietas
# 163. Sumber Benih
# 164. Luas Lahan
# 165. Produktivitas
# 166. Pola Tanam
# 167. Sistem Budidaya
# 168. Pengairan
# 169. Kepemilikan Lahan
# 170. Jenis Pemanfaatan Lahan
# 171. Nama Tanaman.1
# 172. Jangka Tanam
# 173. Jenis Tanaman
# 174. Luas
# 175. Tegakan (batang)
# 176. Tahun Tanam
# 177. Produktivitas (Ton/Ha)
# 178. Pemanfaatan Hasil
# 179. Kepemilikan Lahan.1
# 180. Nama Tempat Lahan
# 181. Sapi
# 182. Kerbau
# 183. Kambing
# 184. Ayam.3
# 185. Bebek
# 186. Babi
# 187. Kuda
# 188. Jumlah Hasil (Kg)
# 189. Sumber Pakan
# 190. Kepemilikan
# 191. Jenis Ikan
# 192. Luas Kolam
# 193. Masa Panen
# 194. Sistem Budidaya.1
# 195. Pasca Panen
# 196. Pemanfaatan Hasil Panen
# 197. Kepemilikan Lahan.2
# 198. Nama Area Tangkap
# 199. Jenis Ikan.1
# 200. Jumlah Hasil
# 201. Pemanfaatan Hasil Tangkap
# 202. Januari
# 203. Februari
# 204. Maret
# 205. April
# 206. Mei
# 207. Juni
# 208. Juli
# 209. Agustus
# 210. September
# 211. Oktober
# 212. November
# 213. Desember
# 214. Januari.1
# 215. Februari.1
# 216. Maret.1
# 217. April.1
# 218. Mei.1
# 219. Juni.1
# 220. Juli.1
# 221. Agustus.1
# 222. September.1
# 223. Oktober.1
# 224. November.1
# 225. Desember.1
# 226. Januari.2
# 227. Februari.2
# 228. Maret.2
# 229. April.2
# 230. Mei.2
# 231. Juni.2
# 232. Juli.2
# 233. Agustus.2
# 234. September.2
# 235. Oktober.2
# 236. November.2
# 237. Desember.2
# 238. Nama Produk
# 239. Jenis Usaha
# 240. Jumlah Produksi
# 241. Proses Produksi
# 242. Pemanfaatan Hasil Produksi
# 243. Sumber Limbah
# 244. Pengolahan
# 245. Hasil Daur Ulang
# 246. Luas Lahan Usaha m2
# 247. Luas Lahan Rumah m2
# 248. Luas Bangunan Rumah m2
# 249. Luas Bangunan Usaha m2
# 250. Mesin dan Alat Kerja
# 251. Jumlah (unit)
# 252. Apakah pernah ada bayi yang meninggal?
# 253. Jika ada, berapa jumlahnya?
# 254. Apakah balita selalu diperiksa ke Posyandu?
# 255. Jumlah Lansia
# 256. Anggota keluarga yang sering sakit
# 257. Jenis penyakit yang sering diderita
# 258. Kemana biasa berobat?
# 259. Apakah pernah dapat bantuan dari pemerintah?
# 260. Kalau iya, apa bentuk bantuan tersebut?
# 261. Jumlah difabel (berkebutuhan khusus)
# 262. Jenis Difabel
# 263. Memiliki anak usia kurang dari 5 tahun
# 264. Tinggi badan anak
# 265. Berat badan anak
# 266. Apakah anak mengalami kasus gizi buruk?
# 267. Apakah anak mengalami kekurangan gizi?
# 268. SourceFile

# %%
df = pd.concat(
    [df[['ID', 'Desa/Kelurahan', 'Nama Kepala Keluarga', 'Pekerjaan', 'Pendapatan Bulanan (Rp.)', 'Sumber Listrik',
    'Air Bersih', 'Iuran BPJS', 'Obat', 'Pulsa Ponsel',
    'Nama Tanaman', 'Sumber Benih', 'Luas Lahan', 'Produktivitas', 'Pola Tanam', 'Sistem Budidaya', 'Pengairan',
    'Pupuk', 'Pestisida/Herbisida/Fungisida', 'Benih', 'Upah Buruh', 'Sewa Alat dan Mesin Pertanian', 
    'Sapi', 'Kerbau', 'Kambing', 'Ayam.3', 'Bebek', 'Babi', 'Kuda', 'Jumlah Hasil (Kg)', 'Sumber Pakan',
    'Nama Area Tangkap', 'Jenis Ikan.1', 'Jumlah Hasil', 'Pemanfaatan Hasil Tangkap',
    'Sumber Limbah', 'Pengolahan', 'Luas Lahan Usaha m2', 'Luas Lahan Rumah m2', 'Luas Bangunan Rumah m2',
    'Apakah balita selalu diperiksa ke Posyandu?', 'Jumlah Lansia', 'Anggota keluarga yang sering sakit', 
    'Apakah pernah dapat bantuan dari pemerintah?', 'Kalau iya, apa bentuk bantuan tersebut?'
        ]]],
    axis=1
)

# %%
df
# Out:
#         ID Desa/Kelurahan    Nama Kepala Keluarga             Pekerjaan  \
# 0    22180         Lolong   Natalia Benga Blolong  Petani atau Nelayan;
# 1    22190       Paubokol          Marianus Nurak  Petani atau Nelayan;
# 2    22195       Paubokol            Viktor Gelak  Petani atau Nelayan;
# 3    22200       Paubokol             Yoseph Kujo  Petani atau Nelayan;
# 4    22205       Paubokol    Hendrikus Laran Ujan  Petani atau Nelayan;
# ..     ...            ...                     ...                   ...
# 876  24866       Todanara         Longginus Lango  Petani atau Nelayan;
# 877  24867       Todanara      Elias Ola Domaking  Petani atau Nelayan;
# 878  24869       Todanara  Antonius Yanto Matarau      Karyawan Swasta;
# 879  24887      Labalimut             Petrus Asan              lainnya;
# 880  24957       Todanara       Hendrikus Kewaman  Petani atau Nelayan;
#
#     Pendapatan Bulanan (Rp.) Sumber Listrik Air Bersih Iuran BPJS    Obat  \
# 0                    200000;            PLN       PDAM         0;      0;
# 1                    800000;            PLN   Mata Air         0;      0;
# 2                    100000;            PLN   Mata Air         0;      0;
# 3                    400000;            PLN   Mata Air         0;      0;
# 4                    600000;            PLN   Mata Air         0;  10000;
# ..                       ...            ...        ...        ...     ...
# 876                  500000;            PLN     Sungai         0;      0;
# 877                  200000;            PLN     Sungai         0;      0;
# 878                 1700000;            PLN     Sungai     80000;      0;
# 879                 4000000;            PLN       PDAM     35000;      0;
# 880                  200000;            PLN     Sungai         0;      0;
#
#     Pulsa Ponsel  ...  Sumber Limbah     Pengolahan Luas Lahan Usaha m2  \
# 0         20000;  ...  Rumah Tangga;  Tidak Diolah;                  0;
# 1        600000;  ...  Rumah Tangga;     Tidak ada;                  0;
# 2             0;  ...  Rumah Tangga;     Tidak ada;                  0;
# 3        600000;  ...     Tidak ada;     Tidak ada;                  0;
# 4        600000;  ...  Rumah Tangga;     Tidak ada;                  0;
# ..           ...  ...            ...            ...                 ...
# 876      100000;  ...  Rumah Tangga;  Tidak Diolah;                  0;
# 877       50000;  ...            NaN            NaN                   ;
# 878      200000;  ...  Rumah Tangga;  Tidak Diolah;                  0;
# 879       50000;  ...  Rumah Tangga;  Tidak Diolah;                  0;
# 880       20000;  ...  Rumah Tangga;  Tidak Diolah;                  0;
#
#     Luas Lahan Rumah m2 Luas Bangunan Rumah m2  \
# 0               0.1140;                     0;
# 1                  300;                    48;
# 2                  750;                    24;
# 3                 1250;                    54;
# 4                  400;                    30;
# ..                  ...                    ...
# 876             428.22;                175.33;
# 877             505.85;                113.55;
# 878                   ;                      ;
# 879                  0;                    80;
# 880             417.66;                155.03;
#
#     Apakah balita selalu diperiksa ke Posyandu? Jumlah Lansia  \
# 0                                    Tidak ada;            0;
# 1                                       Sering;            0;
# 2                                    Tidak ada;            1;
# 3                                       Sering;            0;
# 4                                       Sering;            0;
# ..                                          ...           ...
# 876                                     Sering;            2;
# 877                               Tidak Pernah;            1;
# 878                                  Tidak ada;            0;
# 879                                  Tidak ada;            2;
# 880                                  Tidak ada;            2;
#
#     Anggota keluarga yang sering sakit  \
# 0                              Famili;
# 1                                Anak;
# 2                           Tidak ada;
# 3                           Tidak ada;
# 4                           Tidak ada;
# ..                                 ...
# 876                             Istri;
# 877                         Tidak ada;
# 878                         Tidak ada;
# 879                             Istri;
# 880                              Anak;
#
#     Apakah pernah dapat bantuan dari pemerintah?  \
# 0                                        Pernah;
# 1                                        Pernah;
# 2                                        Pernah;
# 3                                        Pernah;
# 4                                        Pernah;
# ..                                           ...
# 876                                      Pernah;
# 877                                      Pernah;
# 878                                   Tidak ada;
# 879                                       Tidak;
# 880                                   Tidak ada;
#
#     Kalau iya, apa bentuk bantuan tersebut?
# 0                                    Tunai;
# 1                                    Tunai;
# 2                                    Tunai;
# 3                                    Tunai;
# 4                                    Tunai;
# ..                                      ...
# 876                             Pengobatan;
# 877                                  Tunai;
# 878                              Tidak ada;
# 879                              Tidak ada;
# 880                              Tidak ada;
#
# [881 rows x 45 columns]

# %%
df.rename(columns={'Desa/Kelurahan': 'Desa'}, inplace=True)
df.rename(columns={'Pendapatan Bulanan (Rp.)': 'Pendapatan Bulanan'}, inplace=True)
df.rename(columns={'Obat': 'Pembelian Obat'}, inplace=True)
df.rename(columns={'Pulsa Ponsel': 'Pembelian Pulsa'}, inplace=True)
df.rename(columns={'Produktivitas': 'Produksi'}, inplace=True)
df.rename(columns={'Pupuk': 'Pembelian Pupuk'}, inplace=True)
df.rename(columns={'Pestisida/Herbisida/Fungisida': 'Pembelian Pestisida'}, inplace=True)
df.rename(columns={'Benih': 'Pembelian Benih'}, inplace=True)
df.rename(columns={'Sapi': 'Memiliki Sapi'}, inplace=True)
df.rename(columns={'Kerbau': 'Memiliki Kerbau'}, inplace=True)
df.rename(columns={'Kambing': 'Memiliki Kambing'}, inplace=True)
df.rename(columns={'Ayam.3': 'Memiliki Ayam'}, inplace=True)
df.rename(columns={'Bebek': 'Memiliki Bebek'}, inplace=True)
df.rename(columns={'Babi': 'Memiliki Babi'}, inplace=True)
df.rename(columns={'Kuda': 'Memiliki Kuda'}, inplace=True)
df.rename(columns={'Jumlah Hasil (Kg)': 'Ternak dimiliki (Kg)'}, inplace=True)
df.rename(columns={'Sumber Pakan': 'Sumber Pakan Ternak'}, inplace=True)
df.rename(columns={'Nama Area Tangkap': 'Nama Area Perikanan Tangkap'}, inplace=True)
df.rename(columns={'Jenis Ikan.1': 'Jenis Ikan Tangkap'}, inplace=True)
df.rename(columns={'Jumlah Hasil': 'Hasil Tangkapan'}, inplace=True)
df.rename(columns={'Pengolahan': 'Pengolahan Limbah'}, inplace=True)
df.rename(columns={'Apakah balita selalu diperiksa ke Posyandu?': 'Balita diperiksa di Posyandu'}, inplace=True)
df.rename(columns={'Apakah pernah dapat bantuan dari pemerintah?': 'Pernah dapat bantuan dari pemerintah'}, inplace=True)
df.rename(columns={'Kalau iya, apa bentuk bantuan tersebut?': 'Bentuk bantuan pemerintah'}, inplace=True)

# %%
df['ID'] = df['ID'].astype('object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 881 entries, 0 to 880
# Data columns (total 45 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   ID                                    881 non-null    object
#  1   Desa                                  881 non-null    object
#  2   Nama Kepala Keluarga                  881 non-null    object
#  3   Pekerjaan                             870 non-null    object
#  4   Pendapatan Bulanan                    870 non-null    object
#  5   Sumber Listrik                        881 non-null    object
#  6   Air Bersih                            881 non-null    object
#  7   Iuran BPJS                            864 non-null    object
#  8   Pembelian Obat                        864 non-null    object
#  9   Pembelian Pulsa                       864 non-null    object
#  10  Nama Tanaman                          696 non-null    object
#  11  Sumber Benih                          696 non-null    object
#  12  Luas Lahan                            696 non-null    object
#  13  Produksi                              696 non-null    object
#  14  Pola Tanam                            696 non-null    object
#  15  Sistem Budidaya                       696 non-null    object
#  16  Pengairan                             696 non-null    object
#  17  Pembelian Pupuk                       864 non-null    object
#  18  Pembelian Pestisida                   864 non-null    object
#  19  Pembelian Benih                       864 non-null    object
#  20  Upah Buruh                            864 non-null    object
#  21  Sewa Alat dan Mesin Pertanian         864 non-null    object
#  22  Memiliki Sapi                         715 non-null    object
#  23  Memiliki Kerbau                       715 non-null    object
#  24  Memiliki Kambing                      715 non-null    object
#  25  Memiliki Ayam                         715 non-null    object
#  26  Memiliki Bebek                        715 non-null    object
#  27  Memiliki Babi                         715 non-null    object
#  28  Memiliki Kuda                         715 non-null    object
#  29  Ternak dimiliki (Kg)                  715 non-null    object
#  30  Sumber Pakan Ternak                   715 non-null    object
#  31  Nama Area Perikanan Tangkap           251 non-null    object
#  32  Jenis Ikan Tangkap                    251 non-null    object
#  33  Hasil Tangkapan                       251 non-null    object
#  34  Pemanfaatan Hasil Tangkap             251 non-null    object
#  35  Sumber Limbah                         788 non-null    object
#  36  Pengolahan Limbah                     788 non-null    object
#  37  Luas Lahan Usaha m2                   835 non-null    object
#  38  Luas Lahan Rumah m2                   835 non-null    object
#  39  Luas Bangunan Rumah m2                835 non-null    object
#  40  Balita diperiksa di Posyandu          830 non-null    object
#  41  Jumlah Lansia                         830 non-null    object
#  42  Anggota keluarga yang sering sakit    830 non-null    object
#  43  Pernah dapat bantuan dari pemerintah  830 non-null    object
#  44  Bentuk bantuan pemerintah             830 non-null    object
# dtypes: object(45)
# memory usage: 309.9+ KB

# %%
df.isna().sum()
# Out:
# ID                                        0
# Desa                                      0
# Nama Kepala Keluarga                      0
# Pekerjaan                                11
# Pendapatan Bulanan                       11
# Sumber Listrik                            0
# Air Bersih                                0
# Iuran BPJS                               17
# Pembelian Obat                           17
# Pembelian Pulsa                          17
# Nama Tanaman                            185
# Sumber Benih                            185
# Luas Lahan                              185
# Produksi                                185
# Pola Tanam                              185
# Sistem Budidaya                         185
# Pengairan                               185
# Pembelian Pupuk                          17
# Pembelian Pestisida                      17
# Pembelian Benih                          17
# Upah Buruh                               17
# Sewa Alat dan Mesin Pertanian            17
# Memiliki Sapi                           166
# Memiliki Kerbau                         166
# Memiliki Kambing                        166
# Memiliki Ayam                           166
# Memiliki Bebek                          166
# Memiliki Babi                           166
# Memiliki Kuda                           166
# Ternak dimiliki (Kg)                    166
# Sumber Pakan Ternak                     166
# Nama Area Perikanan Tangkap             630
# Jenis Ikan Tangkap                      630
# Hasil Tangkapan                         630
# Pemanfaatan Hasil Tangkap               630
# Sumber Limbah                            93
# Pengolahan Limbah                        93
# Luas Lahan Usaha m2                      46
# Luas Lahan Rumah m2                      46
# Luas Bangunan Rumah m2                   46
# Balita diperiksa di Posyandu             51
# Jumlah Lansia                            51
# Anggota keluarga yang sering sakit       51
# Pernah dapat bantuan dari pemerintah     51
# Bentuk bantuan pemerintah                51
# dtype: int64

# %% [markdown]
# ## Per atribut

# %%
df['Pekerjaan'].value_counts()
# Out:
# Pekerjaan
# Petani atau Nelayan;                         534
# lainnya;                                      91
# Wiraswasta;                                   75
# PNS;                                          60
# Karyawan Swasta;                              39
# Tidak ada;                                    33
# Buruh Tani;                                   33
# Petani atau Nelayan; Petani atau Nelayan;      2
# Wiraswasta; lainnya; Tidak ada;                1
# lainnya; Petani atau Nelayan;                  1
# Petani atau Nelayan; lainnya;                  1
# Name: count, dtype: int64

# %%
df['Pendapatan Bulanan'].value_counts()
# Out:
# Pendapatan Bulanan
# 500000;     118
# 1000000;    116
# 2000000;     51
# 1500000;     45
# 300000;      44
#            ...
# 358000;       1
# 1540000;      1
# 1022330;      1
# 5400000;      1
# 7830000;      1
# Name: count, Length: 130, dtype: int64

# %%
df['Sumber Listrik'].value_counts()
# Out:
# Sumber Listrik
# PLN          871
# Tidak ada      5
# Bukan PLN      5
# Name: count, dtype: int64

# %%
df['Air Bersih'].value_counts()
# Out:
# Air Bersih
# PDAM          430
# Sumur Bor     143
# Mata Air      112
# Sungai         66
# Air Hujan      64
# Sumur Gali     61
# Air Galon       5
# Name: count, dtype: int64

# %%
df['Iuran BPJS'].value_counts()
# Out:
# Iuran BPJS
# 0;         512
# ;          224
# 35000;      14
# 420000;      9
# 150000;      6
#           ...
# 30000;       1
# 25500;       1
# 38500;       1
# 20222;       1
# 272000;      1
# Name: count, Length: 65, dtype: int64

# %%
df['Pembelian Obat'].value_counts()
# Out:
# Pembelian Obat
# 0;          503
# ;           208
# 10000;       34
# 100000;      13
# 20000;       12
# 50000;       10
# 5000;         8
# 25000;        8
# 120000;       8
# 30000;        7
# 15000;        6
# 200000;       5
# 0; 0;         4
# 150000;       4
# 240000;       4
# ; ;           3
# 60000;        3
# 75000;        2
# 250000;       2
# 0; ;          2
# 96000;        1
# 51000;        1
# 72000;        1
# 40000;        1
# 216000;       1
# 4000;         1
# 3000000;      1
# 5900;         1
# 80000;        1
# ; ; ;         1
# 1200000;      1
# 160000;       1
# 12000;        1
# 1000000;      1
# 600000;       1
# 2000000;      1
# ; 0;          1
# 13500;        1
# Name: count, dtype: int64

# %%
df['Pembelian Pulsa'].value_counts()
# Out:
# Pembelian Pulsa
# 0;          139
# 50000;      102
# 100000;      94
# ;            57
# 600000;      37
#            ...
# 816000;       1
# 1980000;      1
# 2700000;      1
# 408000;       1
# 23000;        1
# Name: count, Length: 117, dtype: int64

# %%
df['Nama Tanaman'].value_counts()
# Out:
# Nama Tanaman
# Jagung;                                                                  166
# Jagung; Ubi Kayu;                                                         56
# Jagung Lokal;                                                             46
# Padi;                                                                     38
# Padi; Jagung;                                                             28
#                                                                         ...
# Jagung; Kacang Tanah;                                                      1
# Jagung; Mentimun; Kacang Tanah; Terong; Cabai; Bayam; Sawi; Kangkung;      1
# Padi; Jagung; Cabai; Sawi; Kangkung;                                       1
# Padi Lokal; Jagung ; Ubi Kayu;                                             1
# Padi; Jagung ; Jagung ;                                                    1
# Name: count, Length: 148, dtype: int64

# %%
df['Sumber Benih'].value_counts()
# Out:
# Sumber Benih
# Tangkar Sendiri;                                                                                                                                            232
# Tangkar Sendiri; Tangkar Sendiri;                                                                                                                           105
# Tangkar Sendiri; Tangkar Sendiri; Tangkar Sendiri;                                                                                                           94
# Tidak ada;                                                                                                                                                   65
# Tangkar Sendiri; Tangkar Sendiri; Tangkar Sendiri; Tangkar Sendiri;                                                                                          27
# Bantuan Pemerintah;                                                                                                                                          22
# Tangkar Sendiri; Tidak ada;                                                                                                                                  21
# Bantuan Pemerintah; Tidak ada;                                                                                                                               19
# Beli;                                                                                                                                                        14
# Tidak ada; Tidak ada;                                                                                                                                         9
# Tangkar Sendiri; Tangkar Sendiri; Tidak ada;                                                                                                                  9
# Bantuan Pemerintah; Bantuan Pemerintah;                                                                                                                       7
# Bantuan Pemerintah; Tangkar Sendiri;                                                                                                                          5
# Tidak ada; Tidak ada; Tidak ada;                                                                                                                              5
# Tidak ada; Tangkar Sendiri;                                                                                                                                   4
# Beli; Beli;                                                                                                                                                   3
# Bantuan Pemerintah; Bantuan Pemerintah; Bantuan Pemerintah;                                                                                                   3
# Tangkar Sendiri; Bantuan Pemerintah; Tangkar Sendiri; Tangkar Sendiri;                                                                                        3
# Tangkar Sendiri; Tangkar Sendiri; Tangkar Sendiri; Tidak ada;                                                                                                 3
# Bantuan Pemerintah; Bantuan Pemerintah; Bantuan Pemerintah; Bantuan Pemerintah;                                                                               3
# Tangkar Sendiri; Tangkar Sendiri; Bantuan Pemerintah;                                                                                                         3
# Tangkar Sendiri; Bantuan Pemerintah; Tangkar Sendiri;                                                                                                         3
# Tangkar Sendiri; Tangkar Sendiri; Tangkar Sendiri; Tangkar Sendiri; Tangkar Sendiri;                                                                          2
# Beli; Beli; Beli;                                                                                                                                             2
# Tidak ada; Tangkar Sendiri; Tangkar Sendiri;                                                                                                                  2
# Tangkar Sendiri; Tidak ada; Tangkar Sendiri;                                                                                                                  2
# Bantuan Pemerintah; Tangkar Sendiri; Tangkar Sendiri;                                                                                                         2
# Bantuan Pemerintah; Tangkar Sendiri; Tangkar Sendiri; Tangkar Sendiri; Tangkar Sendiri;                                                                       1
# Tangkar Sendiri; Tangkar Sendiri; Beli; Tangkar Sendiri;                                                                                                      1
# Bantuan Pemerintah; Tidak ada; Tangkar Sendiri;                                                                                                               1
# Bantuan Pemerintah; Tangkar Sendiri; Bantuan Pemerintah; Bantuan Pemerintah;                                                                                  1
# Tidak ada; Tidak ada; Tidak ada; Bantuan Pemerintah;                                                                                                          1
# Beli; Bantuan Pemerintah; Tangkar Sendiri; Tangkar Sendiri;                                                                                                   1
# Tangkar Sendiri; Tangkar Sendiri; Tangkar Sendiri; Tangkar Sendiri; Tangkar Sendiri; Tangkar Sendiri; Tangkar Sendiri; Tangkar Sendiri; Tangkar Sendiri;      1
# Tangkar Sendiri; Tidak ada; Beli; Beli; Beli;                                                                                                                 1
# Tangkar Sendiri; Beli; Beli;                                                                                                                                  1
# Beli; Beli; Beli; Beli; Beli; Beli; Beli;                                                                                                                     1
# Tangkar Sendiri; Tangkar Sendiri; Tangkar Sendiri; Tidak ada; Tangkar Sendiri;                                                                                1
# Tidak ada; Tidak ada; Tidak ada; Tidak ada; Tidak ada;                                                                                                        1
# Tangkar Sendiri; Tidak ada; Tidak ada;                                                                                                                        1
# Beli; Tidak ada;                                                                                                                                              1
# Tangkar Sendiri; Beli; Beli; Beli;                                                                                                                            1
# Tangkar Sendiri; Tangkar Sendiri; Tidak ada; Tangkar Sendiri;                                                                                                 1
# Beli; Tangkar Sendiri;                                                                                                                                        1
# Tangkar Sendiri; Tangkar Sendiri; Bantuan Pemerintah; Tangkar Sendiri;                                                                                        1
# Tangkar Sendiri; Beli;                                                                                                                                        1
# Beli; Beli; Beli; Beli; Beli; Beli; Beli; Beli;                                                                                                               1
# Tangkar Sendiri; Tangkar Sendiri; Tangkar Sendiri; Beli; Beli;                                                                                                1
# Tangkar Sendiri; Bantuan Pemerintah; Beli;                                                                                                                    1
# Beli; Beli; Beli; Beli;                                                                                                                                       1
# Tangkar Sendiri; Bantuan Pemerintah;                                                                                                                          1
# Tangkar Sendiri; Tidak ada; Tangkar Sendiri; Tangkar Sendiri;                                                                                                 1
# Tangkar Sendiri; Tangkar Sendiri; Tangkar Sendiri; Tangkar Sendiri; Tangkar Sendiri; Tangkar Sendiri;                                                         1
# Tidak ada; Tidak ada; Tidak ada; Tidak ada;                                                                                                                   1
# Name: count, dtype: int64

# %%
df['Luas Lahan'].value_counts()
# Out:
# Luas Lahan
# 1;                   72
# 0.5;                 66
# 1; 1;                37
# 0;                   31
# 0.5; 0.5;            24
#                      ..
# 0.7484; ;             1
# 0.2237; ; ;           1
# 0.5; 0.05; 0.05;      1
# 0.16; 0.16;           1
# 0.50; 0.50; 0.50;     1
# Name: count, Length: 257, dtype: int64

# %%
df['Produksi'].value_counts()
# Out:
# Produksi
# 0;                    41
# 1;                    29
# 0.5;                  24
# ;                     21
# 0.2;                  18
#                       ..
# 0.4; 0.25; 0.25;       1
# 0.0501; 0.25; 0.3;     1
# 0.11; ; ;              1
# 0.35; ; ;              1
# 0.5; 0.5; 0.5;         1
# Name: count, Length: 376, dtype: int64

# %%
df['Pola Tanam'].value_counts()
# Out:
# Pola Tanam
# 1 kali setahun;                                                                                                                                    274
# 1 kali setahun; 1 kali setahun;                                                                                                                    137
# 1 kali setahun; 1 kali setahun; 1 kali setahun;                                                                                                    112
# Tidak ada;                                                                                                                                          55
# 1 kali setahun; 1 kali setahun; 1 kali setahun; 1 kali setahun;                                                                                     42
# 1 kali setahun; Tidak ada;                                                                                                                          28
# Tidak ada; Tidak ada;                                                                                                                                8
# Tidak ada; Tidak ada; Tidak ada;                                                                                                                     5
# 1 kali setahun; 1 kali setahun; Tidak ada;                                                                                                           5
# 3 kali setahun;                                                                                                                                      4
# 1 kali setahun; 1 kali setahun; 1 kali setahun; 1 kali setahun; 1 kali setahun;                                                                      4
# Tidak ada; 1 kali setahun; 1 kali setahun;                                                                                                           3
# 3 kali setahun; 1 kali setahun; 1 kali setahun;                                                                                                      2
# 2 kali setahun; 2 kali setahun;                                                                                                                      2
# 1 kali setahun; 1 kali setahun; 1 kali setahun; 1 kali setahun; 1 kali setahun; 1 kali setahun;                                                      1
# 1 kali setahun; 1 kali setahun; 1 kali setahun; 1 kali setahun; 1 kali setahun; 1 kali setahun; 1 kali setahun;                                      1
# Tidak ada; Tidak ada; Tidak ada; Tidak ada; Tidak ada;                                                                                               1
# 1 kali setahun; 1 kali setahun; 3 kali setahun; 3 kali setahun; 3 kali setahun;                                                                      1
# 1 kali setahun; 1 kali setahun; 1 kali setahun; 1 kali setahun; 1 kali setahun; 1 kali setahun; 1 kali setahun; 1 kali setahun; 1 kali setahun;      1
# Tidak ada; Tidak ada; Tidak ada; 1 kali setahun;                                                                                                     1
# 1 kali setahun; Tidak ada; 1 kali setahun;                                                                                                           1
# 2 kali setahun; 1 kali setahun; 1 kali setahun; 1 kali setahun;                                                                                      1
# 3 kali setahun; 1 kali setahun; 1 kali setahun; 1 kali setahun;                                                                                      1
# 3 kali setahun; 3 kali setahun; 3 kali setahun; 3 kali setahun; 3 kali setahun; 3 kali setahun; 3 kali setahun; 3 kali setahun;                      1
# 1 kali setahun; 1 kali setahun; 2 kali setahun; 2 kali setahun; 2 kali setahun;                                                                      1
# 1 kali setahun; 2 kali setahun; 2 kali setahun; 1 kali setahun;                                                                                      1
# 1 kali setahun; 2 kali setahun;                                                                                                                      1
# 2 kali setahun; 1 kali setahun;                                                                                                                      1
# 1 kali setahun; Tidak ada; Tidak ada;                                                                                                                1
# Name: count, dtype: int64

# %%
df['Sistem Budidaya'].value_counts()
# Out:
# Sistem Budidaya
# Organik;                                                                                                                         167
# Organik; Organik;                                                                                                                 91
# Organik; Organik; Organik;                                                                                                        81
# Tidak ada;                                                                                                                        65
# Semi Organik;                                                                                                                     64
# Kimia;                                                                                                                            37
# Organik; Organik; Organik; Organik;                                                                                               34
# Semi Organik; Tidak ada;                                                                                                          23
# Semi Organik; Semi Organik; Semi Organik;                                                                                         20
# Semi Organik; Semi Organik;                                                                                                       19
# Tidak ada; Tidak ada;                                                                                                             17
# Organik; Tidak ada;                                                                                                               16
# Semi Organik; Semi Organik; Tidak ada;                                                                                             7
# Tidak ada; Tidak ada; Tidak ada;                                                                                                   7
# Semi Organik; Semi Organik; Organik;                                                                                               4
# Kimia; Kimia;                                                                                                                      4
# Semi Organik; Semi Organik; Semi Organik; Tidak ada;                                                                               3
# Semi Organik; Semi Organik; Semi Organik; Semi Organik;                                                                            3
# Organik; Semi Organik;                                                                                                             3
# Organik; Organik; Organik; Organik; Organik;                                                                                       3
# Semi Organik; Organik;                                                                                                             2
# Semi Organik; Organik; Organik;                                                                                                    2
# Semi Organik; Semi Organik; Semi Organik; Organik;                                                                                 2
# Organik; Semi Organik; Semi Organik;                                                                                               2
# Tidak ada; Organik; Organik;                                                                                                       2
# Tidak ada; Tidak ada; Tidak ada; Tidak ada; Tidak ada;                                                                             1
# Tidak ada; Tidak ada; Tidak ada; Semi Organik; Semi Organik;                                                                       1
# Kimia; Semi Organik;                                                                                                               1
# Semi Organik; Semi Organik; Semi Organik; Semi Organik; Semi Organik; Semi Organik; Semi Organik; Semi Organik; Semi Organik;      1
# Tidak ada; Tidak ada; Tidak ada; Organik;                                                                                          1
# Semi Organik; Tidak ada; Tidak ada;                                                                                                1
# Organik; Kimia; Kimia; Kimia; Kimia;                                                                                               1
# Kimia; Organik;                                                                                                                    1
# Organik; Organik; Organik; Organik; Organik; Organik; Organik; Organik;                                                            1
# Semi Organik; Semi Organik; Semi Organik; Semi Organik; Semi Organik; Semi Organik; Semi Organik;                                  1
# Kimia; Kimia; Kimia;                                                                                                               1
# Kimia; Semi Organik; Tidak ada;                                                                                                    1
# Kimia; Semi Organik; Semi Organik; Kimia;                                                                                          1
# Organik; Semi Organik; Semi Organik; Semi Organik;                                                                                 1
# Kimia; Semi Organik; Organik;                                                                                                      1
# Organik; Organik; Organik; Organik; Organik; Organik;                                                                              1
# Organik; Semi Organik; Semi Organik; Semi Organik; Semi Organik;                                                                   1
# Organik; Organik; Tidak ada; Organik;                                                                                              1
# Name: count, dtype: int64

# %%
df['Pengairan'].value_counts()
# Out:
# Pengairan
# Tadah Hujan;                                                                                                            263
# Tadah Hujan; Tadah Hujan;                                                                                               116
# Tadah Hujan; Tadah Hujan; Tadah Hujan;                                                                                  100
# Tidak ada;                                                                                                               59
# Tadah Hujan; Tidak ada;                                                                                                  37
# Tadah Hujan; Tadah Hujan; Tadah Hujan; Tadah Hujan;                                                                      36
# Tidak ada; Tidak ada;                                                                                                    11
# Tadah Hujan; Tadah Hujan; Tidak ada;                                                                                      9
# Non Teknis; Non Teknis; Non Teknis;                                                                                       9
# Non Teknis; Non Teknis;                                                                                                   9
# Teknis;                                                                                                                   6
# Tidak ada; Tidak ada; Tidak ada;                                                                                          6
# Non Teknis;                                                                                                               5
# Tadah Hujan; Tadah Hujan; Tadah Hujan; Tadah Hujan; Tadah Hujan;                                                          5
# Tadah Hujan; Tadah Hujan; Tadah Hujan; Tidak ada;                                                                         3
# Non Teknis; Tadah Hujan; Tadah Hujan;                                                                                     2
# Non Teknis; Tidak ada;                                                                                                    2
# Non Teknis; Tidak ada; Tidak ada;                                                                                         1
# Tidak ada; Tadah Hujan;                                                                                                   1
# Tidak ada; Tidak ada; Tidak ada; Tadah Hujan;                                                                             1
# Non Teknis; Tadah Hujan; Non Teknis; Non Teknis;                                                                          1
# Tadah Hujan; Tadah Hujan; Tadah Hujan; Tadah Hujan; Tadah Hujan; Tadah Hujan; Tadah Hujan;                                1
# Non Teknis; Non Teknis; Non Teknis; Non Teknis;                                                                           1
# Tadah Hujan; Tadah Hujan; Tadah Hujan; Tadah Hujan; Tadah Hujan; Tadah Hujan; Tadah Hujan; Tadah Hujan; Tadah Hujan;      1
# Teknis; Teknis; Teknis; Teknis; Teknis; Teknis; Teknis; Teknis;                                                           1
# Tadah Hujan; Tadah Hujan; Tidak ada; Tadah Hujan;                                                                         1
# Tadah Hujan; Tadah Hujan; Non Teknis; Tadah Hujan;                                                                        1
# Teknis; Tadah Hujan; Tadah Hujan;                                                                                         1
# Teknis; Tadah Hujan; Tadah Hujan; Tadah Hujan;                                                                            1
# Teknis; Teknis; Teknis; Teknis; Teknis;                                                                                   1
# Tadah Hujan; Teknis; Teknis; Tadah Hujan;                                                                                 1
# Teknis; Tadah Hujan;                                                                                                      1
# Tadah Hujan; Tadah Hujan; Tadah Hujan; Tadah Hujan; Tadah Hujan; Tadah Hujan;                                             1
# Tidak ada; Tadah Hujan; Tadah Hujan;                                                                                      1
# Tidak ada; Tidak ada; Tidak ada; Tidak ada; Tidak ada;                                                                    1
# Name: count, dtype: int64

# %%
df['Pembelian Pupuk'].value_counts()
# Out:
# Pembelian Pupuk
# 0;               509
# ;                232
# 150000;           30
# 50000;            11
# 300000;            5
# 11000;             5
# 12500;             4
# 1800000;           3
# 70000;             3
# 25000;             3
# 1500000;           3
# 0; 0;              3
# 75000;             3
# 15000;             2
# ; ;                2
# 600000;            2
# 1200000;           2
# 250000;            2
# 500000;            2
# 0; ;               2
# 22000;             1
# 112500;            1
# 37500;             1
# 80000;             1
# 13000;             1
# 28000;             1
# 260000;            1
# 62500;             1
# 34000;             1
# 140000;            1
# 105000;            1
# 11250;             1
# 16500;             1
# 16750; 16750;      1
# 112000;            1
# 2550000;           1
# 340000;            1
# ; ; ;              1
# 35000;             1
# 2880000;           1
# 150000; ;          1
# ; 0;               1
# 30000;             1
# 20000;             1
# 120000;            1
# 40000;             1
# 200000;            1
# 100000;            1
# 60000;             1
# 135000;            1
# 750000;            1
# 67500;             1
# 130000;            1
# 17000;             1
# 275000;            1
# 420000;            1
# Name: count, dtype: int64

# %%
df['Pembelian Pestisida'].value_counts()
# Out:
# Pembelian Pestisida
# 0;          421
# ;           212
# 120000;      19
# 80000;       14
# 100000;      14
#            ...
# 400000;       1
# 140000;       1
# 6250;         1
# 2160000;      1
# 45000;        1
# Name: count, Length: 85, dtype: int64

# %%
df['Pembelian Benih'].value_counts()
# Out:
# Pembelian Benih
# 0;           560
# ;            239
# 50000;         8
# 20000;         5
# 0; 0;          4
# 100000;        3
# 15000;         3
# 10000;         3
# ; ;            3
# 90000;         2
# 0; ;           2
# 200000;        2
# 120000;        2
# 85000;         2
# 300000;        2
# 175000;        1
# 25000;         1
# 5000;          1
# 750000;        1
# 60000;         1
# 540000;        1
# 12500;         1
# 45000;         1
# 70000;         1
# 180000;        1
# 16000;         1
# 450000;        1
# 425000;        1
# 240000;        1
# 600000;        1
# 810000;        1
# 1.000000;      1
# 30000;         1
# 00;            1
# 7000;          1
# ; 0;           1
# 12000;         1
# ; ; ;          1
# 75000;         1
# Name: count, dtype: int64

# %%
df['Upah Buruh'].value_counts()
# Out:
# Upah Buruh
# 0;          540
# ;           235
# 150000;       8
# 200000;       7
# 250000;       6
# 500000;       6
# 100000;       6
# 50000;        6
# 0; 0;         4
# 1000000;      4
# 1500000;      4
# 75000;        4
# 300000;       3
# 600000;       3
# ; ;           3
# 0; ;          2
# 7000000;      2
# 750000;       2
# 2725000;      1
# 240000;       1
# 37500;        1
# 375000;       1
# 2540000;      1
# 100;          1
# 360000;       1
# 720000;       1
# 1400000;      1
# 15000;        1
# ; 0;          1
# 1750000;      1
# 2000000;      1
# 80000;        1
# ; ; ;         1
# 400000;       1
# 20000;        1
# 520000;       1
# 60000;        1
# Name: count, dtype: int64

# %%
df['Sewa Alat dan Mesin Pertanian'].value_counts()
# Out:
# Sewa Alat dan Mesin Pertanian
# 0;          568
# ;           238
# 100000;       9
# 150000;       5
# 1000000;      4
# 0; 0;         4
# 500000;       3
# ; ;           3
# 40000;        3
# 400000;       3
# 250000;       2
# 600000;       2
# 0; ;          2
# 125000;       2
# 20000;        2
# ; 0;          1
# 580000;       1
# 1200000;      1
# 50000;        1
# ; ; ;         1
# 120000;       1
# 58000;        1
# 900000;       1
# 80000;        1
# 200000;       1
# 480000;       1
# 45000;        1
# 800000;       1
# 300000;       1
# Name: count, dtype: int64

# %%
df['Memiliki Sapi'].value_counts()
# Out:
# Memiliki Sapi
# 0;       401
# ;        197
# 1;        31
# 2;        24
# 3;        19
# 5;        10
# 0; 0;      7
# 4;         7
# 6;         4
# 7;         3
# ; ;        3
# 8;         1
# 1; 1;      1
# 0; ;       1
# 3; 1;      1
# 2144;      1
# 9;         1
# 1; ;       1
# 14;        1
# 12;        1
# Name: count, dtype: int64

# %%
df['Memiliki Kerbau'].value_counts()
# Out:
# Memiliki Kerbau
# 0;       467
# ;        233
# 0; 0;      7
# ; ;        5
# 0; ;       2
# 7;         1
# Name: count, dtype: int64

# %%
df['Memiliki Kambing'].value_counts()
# Out:
# Memiliki Kambing
# 0;         285
# ;          113
# 2;          66
# 1;          62
# 3;          53
# 4;          35
# 5;          23
# 10;         15
# 8;          10
# 6;           9
# 7;           8
# 20;          6
# 0; 0;        4
# 12;          3
# 15;          2
# 2; ;         2
# 40;          2
# ; 3;         1
# 13;          1
# 50;          1
# ; ;          1
# 19;          1
# 0; 15;       1
# 23;          1
# 30;          1
# 2; 2;        1
# 60;          1
# 4; 3;        1
# 11;          1
# 9;           1
# 0; ;         1
# 14;          1
# 5; ;         1
# 12; 12;      1
# Name: count, dtype: int64

# %%
df['Memiliki Ayam'].value_counts()
# Out:
# Memiliki Ayam
# 0;        128
# ;          76
# 5;         69
# 2;         63
# 10;        62
# 3;         55
# 4;         38
# 1;         32
# 20;        29
# 15;        23
# 7;         23
# 6;         23
# 8;         21
# 12;        13
# 30;         7
# 25;         6
# 13;         4
# 9;          4
# 16;         3
# 11;         3
# 14;         2
# 50;         2
# 20; 0;      2
# 17;         2
# 2; ;        2
# 100;        2
# 0; 0;       1
# 24;         1
# 50; ;       1
# 20; ;       1
# 6; 0;       1
# 350;        1
# 4; 0;       1
# 6; 6;       1
# 21;         1
# 23;         1
# ; 10;       1
# 36;         1
# 75;         1
# 32;         1
# 105;        1
# 60;         1
# 5; 0;       1
# 22;         1
# ; ;         1
# 80;         1
# 5; 5;       1
# Name: count, dtype: int64

# %%
df['Memiliki Bebek'].value_counts()
# Out:
# Memiliki Bebek
# 0;       448
# ;        218
# 3;         9
# 0; 0;      7
# 2;         6
# ; ;        5
# 1;         3
# 20;        3
# 4;         2
# 0; ;       2
# 8;         2
# 5;         2
# 11;        2
# 12;        1
# 10;        1
# 15;        1
# 6;         1
# 30;        1
# 19;        1
# Name: count, dtype: int64

# %%
df['Memiliki Babi'].value_counts()
# Out:
# Memiliki Babi
# 0;       187
# 1;       171
# 2;       115
# ;        107
# 3;        43
# 4;        32
# 6;        13
# 5;        13
# 7;         6
# 8;         6
# 9;         3
# 2; 2;      2
# 0; 1;      2
# 12;        2
# 0; 0;      2
# 15;        1
# 3; ;       1
# 3; 3;      1
# 1; 1;      1
# 1; 2;      1
# 0; 3;      1
# 16;        1
# 2; ;       1
# 0; 2;      1
# ; ;        1
# 10;        1
# Name: count, dtype: int64

# %%
df['Memiliki Kuda'].value_counts()
# Out:
# Memiliki Kuda
# 0;       455
# ;        229
# 1;        12
# 0; 0;      7
# ; ;        5
# 2;         4
# 0; ;       2
# 8;         1
# Name: count, dtype: int64

# %%
df['Ternak dimiliki (Kg)'].value_counts()
# Out:
# Ternak dimiliki (Kg)
# 0;       208
# ;        191
# 5;        13
# 10;       11
# 50;       10
#         ...
# 224;       1
# 34;        1
# 108;       1
# 44;        1
# 1105;      1
# Name: count, Length: 192, dtype: int64

# %%
df['Sumber Pakan Ternak'].value_counts()
# Out:
# Sumber Pakan Ternak
# Dibuat Sendiri;                    537
# Tidak ada;                          58
# Beli;                               55
# Dilepasliarkan;                     51
# Dibuat Sendiri; Dibuat Sendiri;      8
# Dibuat Sendiri; Tidak ada;           2
# Dibuat Sendiri; Dilepasliarkan;      2
# Beli; Dilepasliarkan;                1
# Beli; Dibuat Sendiri;                1
# Name: count, dtype: int64

# %%
df['Nama Area Perikanan Tangkap'].value_counts()
# Out:
# Nama Area Perikanan Tangkap
# -;                                                                               37
# Tidak ada;                                                                       37
# 0;                                                                               34
# ;                                                                                17
# Laut Flores;                                                                     12
# Pantai Uleha;                                                                    12
# Pantai Lewolein;                                                                  9
# Pesisir Pantai;                                                                   7
# Igo Tapu;                                                                         6
# Teluk Waienga; Teluk Waienga;                                                     5
# Pantai Merdeka;                                                                   4
# Pantai Pada;                                                                      4
# Tidak Ada;                                                                        4
# Teluk Lamadou;                                                                    3
# Dolulolong;                                                                       3
# Perairan Pesisir;                                                                 3
# Pantai Woi Pedan;                                                                 3
# Bota Knipo;                                                                       3
# Menyuluh;                                                                         2
# Laut Flores; Laut Flores; Laut Flores; Laut Flores;                               2
# Teluk Waienga; Teluk Waienga; Teluk Waienga;                                      2
# Teluk Lamadou; Teluk Lamadou; Teluk Lamadou; Teluk Lamadou;                       2
# tidak ada;                                                                        2
# Teluk Waienga;                                                                    2
# Igo Tapu; Igo Tapu;                                                               2
# Teluk Lamadou; Teluk Lamadou;                                                     1
# Teluk Waipukang; Teluk Waipukang; Teluk Waipukang;                                1
# Teluk di Belakang Bandara;                                                        1
# Teluk Lamadou; Teluk Lamadou; Teluk Lamadou;                                      1
# Igotaou (Muruona);                                                                1
# ; ; ; ;                                                                           1
# Teluk Habui;                                                                      1
# Dusun C; Dusun C;                                                                 1
# Teluk Waipukang; Teluk Waipukang; Teluk Waipukang; Teluk Waipukang;               1
# Laut Balauring;                                                                   1
# Teluk Merdeka ;                                                                   1
# Teluk Waienga; Teluk Waienga; Teluk Waienga; Teluk Waienga; Teluk Waienga;        1
# Laut Flores; Pantai Waiau;                                                        1
# Laut Dusun C; Laut Dusun C; Laut Dusun C;                                         1
# Perairan Pesisir; Perairan Pesisir; Perairan Pesisir;                             1
# Wewa Bele; Wewa Bele; Wewa Bele; Wewa Bele;                                       1
# Pantai Loang; Pantai Loang;                                                       1
# Pantai Loang; Pantai Loang; Pantai Loang;                                         1
# Menyuluh; Menyuluh;                                                               1
# Menyuluh; Menyuluh; Menyuluh; Menyuluh;                                           1
# Pantai Woi Pedan; Pantai Woi Pedan; Pantai Woi Pedan;                             1
# Pantai Woi Pedan; Pantai Woi Pedan;                                               1
# Waejarang;                                                                        1
# Pantai Kabelo; Hukung; Kuma Resort; Waejarang;                                    1
# Watodiri; Watodiri;                                                               1
# Laut Kalikur;                                                                     1
# Laut Flores; Laut Flores;                                                         1
# Edam; Edam; Edam; Edam;                                                           1
# Watebelong; Lakarona;                                                             1
# Laut Flores; Laut Flores; Laut Flores; Laut Flores; Laut Flores; Laut Flores;     1
# Teluk Waienga; Teluk Waienga; Teluk Waienga; Teluk Waienga;                       1
# Teluk Waienga ;                                                                   1
# Bola; Noloy;                                                                      1
# Nuha;                                                                             1
# Name: count, dtype: int64

# %%
df['Jenis Ikan Tangkap'].value_counts()
# Out:
# Jenis Ikan Tangkap
# Tidak ada;                         36
# 0;                                 35
# -;                                 31
# ;                                  25
# Batu;                              18
#                                    ..
# Batu; Layang;                       1
# Kakap Merah;                        1
# Beduk; Kakap; Kerang; Teripang;     1
# Teri;                               1
# Melus;                              1
# Name: count, Length: 76, dtype: int64

# %%
df['Hasil Tangkapan'].value_counts()
# Out:
# Hasil Tangkapan
# 0;                 111
# ;                   22
# 2;                  14
# 1;                  10
# 3;                   9
# 5;                   8
# 10;                  8
# 20;                  6
# 4;                   5
# 30;                  3
# 15;                  3
# 5; ;                 3
# 2; 2; 2; 2;          2
# 1; ;                 2
# 10; ; ; ;            2
# 0.2;                 2
# 0.6; ;               2
# ; ; ;                2
# 20; ;                2
# 1; 1; 1; 1;          2
# 50;                  1
# 60;                  1
# 10; 10;              1
# 1.5;                 1
# 2.7; ; ; ; ;         1
# 8;                   1
# 0.3;                 1
# 25;                  1
# 3; ; ; ;             1
# 0.4;                 1
# 4; ; ;               1
# ; ; ; ;              1
# 10; ;                1
# 0.5;                 1
# 3; ; ;               1
# 90; ;                1
# 1; 1; 1;             1
# 150;                 1
# 0.6;                 1
# 15; 15;              1
# 20; ; ; ;            1
# 2; ; ;               1
# 5; 5;                1
# 10; 10; 10; 10;      1
# 0.03; ; ;            1
# 2; 2;                1
# ; ; ; ; ; ;          1
# 5; ; ; ;             1
# 6;                   1
# 15; ; ;              1
# 3; ;                 1
# 2; 4;                1
# 12;                  1
# Name: count, dtype: int64

# %%
df['Pemanfaatan Hasil Tangkap'].value_counts()
# Out:
# Pemanfaatan Hasil Tangkap
# Tidak ada;                                                                                                                                                     130
# Konsumsi Sendiri dan Dijual;                                                                                                                                    42
# Konsumsi Sendiri;                                                                                                                                               38
# Konsumsi Sendiri; Konsumsi Sendiri;                                                                                                                              8
# Konsumsi Sendiri; Konsumsi Sendiri; Konsumsi Sendiri; Konsumsi Sendiri;                                                                                          8
# Konsumsi Sendiri dan Dijual; Konsumsi Sendiri dan Dijual;                                                                                                        6
# Konsumsi Sendiri; Konsumsi Sendiri; Konsumsi Sendiri;                                                                                                            5
# Jual Semua; Jual Semua;                                                                                                                                          2
# Konsumsi Sendiri dan Dijual; Konsumsi Sendiri dan Dijual; Konsumsi Sendiri dan Dijual;                                                                           2
# Jual Semua;                                                                                                                                                      2
# Konsumsi Sendiri dan Dijual; Konsumsi Sendiri dan Dijual; Konsumsi Sendiri dan Dijual; Konsumsi Sendiri dan Dijual;                                              2
# Tidak ada satupun;                                                                                                                                               1
# Konsumsi Sendiri dan Dijual; Konsumsi Sendiri dan Dijual; Tidak ada; Konsumsi Sendiri dan Dijual; Konsumsi Sendiri dan Dijual; Konsumsi Sendiri dan Dijual;      1
# Konsumsi Sendiri; Konsumsi Sendiri dan Dijual;                                                                                                                   1
# Tidak ada; Tidak ada; Tidak ada;                                                                                                                                 1
# Konsumsi Sendiri dan Dijual; Konsumsi Sendiri dan Dijual; Konsumsi Sendiri dan Dijual; Konsumsi Sendiri dan Dijual; Konsumsi Sendiri dan Dijual;                 1
# Tidak ada; Tidak ada; Tidak ada; Tidak ada;                                                                                                                      1
# Name: count, dtype: int64

# %%
df['Sumber Limbah'].value_counts()
# Out:
# Sumber Limbah
# Rumah Tangga;                                                                      483
# Pertanian dan Perkebunan;                                                          133
# Tidak ada;                                                                          53
# Peternakan dan Perikanan;                                                           34
# Rumah Tangga; Pertanian dan Perkebunan;                                             33
# Rumah Tangga; Pertanian dan Perkebunan; Peternakan dan Perikanan;                   21
# Rumah Tangga; Peternakan dan Perikanan;                                             13
# Rumah Tangga; Rumah Tangga;                                                          6
# Pertanian dan Perkebunan; Rumah Tangga;                                              6
# Tidak ada; Tidak ada;                                                                2
# Pertanian dan Perkebunan; Rumah Tangga; Peternakan dan Perikanan;                    1
# Pertanian dan Perkebunan; Peternakan dan Perikanan;                                  1
# Rumah Tangga; Peternakan dan Perikanan; Pertanian dan Perkebunan;                    1
# Rumah Tangga; Pertanian dan Perkebunan; Peternakan dan Perikanan; Rumah Tangga;      1
# Name: count, dtype: int64

# %%
df['Pengolahan Limbah'].value_counts()
# Out:
# Pengolahan Limbah
# Tidak Diolah;                                  410
# Diolah;                                        197
# Tidak ada;                                      96
# Diolah; Tidak Diolah;                           31
# Tidak Diolah; Tidak Diolah;                     12
# Diolah; Diolah;                                  9
# Tidak Diolah; Tidak Diolah; Tidak Diolah;        9
# Tidak Diolah; Diolah; Diolah;                    5
# Tidak Diolah; Diolah;                            3
# Diolah; Tidak Diolah; Diolah;                    2
# Diolah; Diolah; Diolah;                          2
# Tidak ada; Tidak ada;                            2
# Tidak Diolah; Tidak ada; Tidak ada;              2
# Tidak Diolah; Tidak ada;                         1
# Diolah; Tidak Diolah; Tidak Diolah;              1
# Diolah; Tidak ada;                               1
# Tidak Diolah; Diolah; Tidak Diolah;              1
# Tidak ada; Tidak ada; Tidak ada;                 1
# Tidak ada; Tidak Diolah;                         1
# Tidak ada; Diolah;                               1
# Tidak Diolah; Tidak Diolah; Diolah; Diolah;      1
# Name: count, dtype: int64

# %%
df['Luas Lahan Usaha m2'].value_counts()
# Out:
# Luas Lahan Usaha m2
# 0;               386
# ;                137
# 10000;            27
# 5000;             20
# 2500;             16
#                 ...
# 1.500;             1
# 650;               1
# 12500;             1
# 30000; 30000;      1
# 56;                1
# Name: count, Length: 112, dtype: int64

# %%
df['Luas Lahan Rumah m2'].value_counts()
# Out:
# Luas Lahan Rumah m2
# 625;       86
# 400;       38
# 300;       36
# 150;       32
# 200;       23
#            ..
# 1.335;      1
# 338;        1
# 860;        1
# 513;        1
# 417.66;     1
# Name: count, Length: 271, dtype: int64

# %%
df['Luas Bangunan Rumah m2'].value_counts()
# Out:
# Luas Bangunan Rumah m2
# 48;        97
# 35;        96
# 42;        50
# 63;        48
# 54;        43
#            ..
# 12.9;       1
# 86.5;       1
# 37.5;       1
# 1000;       1
# 155.03;     1
# Name: count, Length: 169, dtype: int64

# %%
df['Balita diperiksa di Posyandu'].value_counts()
# Out:
# Balita diperiksa di Posyandu
# Tidak ada;                          539
# Sering;                             261
# Tidak Pernah;                        15
# Sering; Sering;                       4
# Kadang;                               4
# Tidak ada; Tidak ada;                 4
# Sering; Tidak ada;                    1
# Tidak ada; Tidak ada; Tidak ada;      1
# Tidak ada; Sering;                    1
# Name: count, dtype: int64

# %%
df['Jumlah Lansia'].value_counts()
# Out:
# Jumlah Lansia
# 0;          289
# 1;          203
# 2;          194
# ;           126
# 3;            6
# 0; 0;         3
# 2; 2;         2
# 0; 2;         1
# 4;            1
# 0; 4;         1
# ; ;           1
# 2; ;          1
# 1; 1;         1
# 2; 2; 2;      1
# Name: count, dtype: int64

# %%
df['Anggota keluarga yang sering sakit'].value_counts()
# Out:
# Anggota keluarga yang sering sakit
# Tidak ada;                          431
# Istri;                              125
# Suami;                               96
# Anak;                                64
# Famili;                              53
# Orang Tua;                           50
# Tidak ada; Tidak ada;                 6
# Orang Tua; Istri;                     1
# Anak; Tidak ada;                      1
# Suami; Tidak ada;                     1
# Orang Tua; Orang Tua; Orang Tua;      1
# Suami; Suami;                         1
# Name: count, dtype: int64

# %%
df['Pernah dapat bantuan dari pemerintah'].value_counts()
# Out:
# Pernah dapat bantuan dari pemerintah
# Pernah;                    563
# Tidak ada;                 172
# Tidak;                      84
# Pernah; Pernah;              6
# Tidak; Tidak ada;            1
# Tidak ada; Tidak ada;        1
# Tidak ada; Tidak;            1
# Pernah; Tidak ada;           1
# Pernah; Pernah; Pernah;      1
# Name: count, dtype: int64

# %%
df['Bentuk bantuan pemerintah'].value_counts()
# Out:
# Bentuk bantuan pemerintah
# Tunai;                     311
# Tidak ada;                 258
# Pengobatan;                250
# Tunai; Tunai;                4
# Tidak ada; Tidak ada;        3
# Pengobatan; Pengobatan;      2
# Pengobatan; Tidak ada;       1
# Tunai; Tunai; Tunai;         1
# Name: count, dtype: int64

# %% [markdown]
# # Data Transformation

# %% [markdown]
# ### categoric

# %%
def get_max_index(value):
    if pd.isna(value) or not isinstance(value, str):
        return None
        
    value_parts = value.split(';')
    float_values = []
    
    for part in value_parts:
        part = part.strip()
        try:
            if part:
                float_values.append(float(part))
        except ValueError:
            continue
            
    if not float_values:
        return None
        
    max_value = max(float_values)
    
    try:
        return float_values.index(max_value)
    except ValueError:
        return None

# %%
def get_element_by_index(target_str, index):
    if pd.isna(index) or pd.isna(target_str) or not isinstance(target_str, str):
        return np.nan
        
    parts = [p.strip() for p in target_str.split(';') if p.strip()]
    
    index_int = int(index) 
    
    if index_int < len(parts):
        return parts[index_int]
    else:
        return np.nan

# %%
df['Max_Produksi_Index'] = df['Produksi'].apply(get_max_index)
df['Max_Produksi_Index'] = df['Max_Produksi_Index'].astype('Int64')

# %%
df['Max_Produksi_Index'].value_counts()
# Out:
# Max_Produksi_Index
# 0    553
# 1     74
# 2     21
# 3      3
# Name: count, dtype: Int64

# %%
target_cols = ["Nama Tanaman", "Sumber Benih", "Pola Tanam", "Sistem Budidaya", "Pengairan"]

for col in target_cols:
    df[f'Produksi Terbanyak_{col}'] = df.apply(
        lambda row: get_element_by_index(row[col], row['Max_Produksi_Index']),
        axis=1
    )

# %%
df['Max_Hasil_Tangkapan_Index'] = df['Hasil Tangkapan'].apply(get_max_index)
df['Max_Hasil_Tangkapan_Index'] = df['Max_Hasil_Tangkapan_Index'].astype('Int64')

# %%
df['Max_Hasil_Tangkapan_Index'].value_counts()
# Out:
# Max_Hasil_Tangkapan_Index
# 0    224
# 1      1
# Name: count, dtype: Int64

# %%
target_cols = ["Nama Area Perikanan Tangkap", "Jenis Ikan Tangkap", "Pemanfaatan Hasil Tangkap"]

for col in target_cols:
    df[f'Tangkapan Terbanyak_{col}'] = df.apply(
        lambda row: get_element_by_index(row[col], row['Max_Produksi_Index']),
        axis=1
    )

# %%
df.head()
# Out:
#       ID      Desa   Nama Kepala Keluarga             Pekerjaan  \
# 0  22180    Lolong  Natalia Benga Blolong  Petani atau Nelayan;
# 1  22190  Paubokol         Marianus Nurak  Petani atau Nelayan;
# 2  22195  Paubokol           Viktor Gelak  Petani atau Nelayan;
# 3  22200  Paubokol            Yoseph Kujo  Petani atau Nelayan;
# 4  22205  Paubokol   Hendrikus Laran Ujan  Petani atau Nelayan;
#
#   Pendapatan Bulanan Sumber Listrik Air Bersih Iuran BPJS Pembelian Obat  \
# 0            200000;            PLN       PDAM         0;             0;
# 1            800000;            PLN   Mata Air         0;             0;
# 2            100000;            PLN   Mata Air         0;             0;
# 3            400000;            PLN   Mata Air         0;             0;
# 4            600000;            PLN   Mata Air         0;         10000;
#
#   Pembelian Pulsa  ... Max_Produksi_Index Produksi Terbanyak_Nama Tanaman  \
# 0          20000;  ...               <NA>                             NaN
# 1         600000;  ...                  0                          Jagung
# 2              0;  ...                  0                            Padi
# 3         600000;  ...                  0                            Padi
# 4         600000;  ...                  0                            Padi
#
#   Produksi Terbanyak_Sumber Benih Produksi Terbanyak_Pola Tanam  \
# 0                             NaN                           NaN
# 1                 Tangkar Sendiri                1 kali setahun
# 2                 Tangkar Sendiri                1 kali setahun
# 3                 Tangkar Sendiri                1 kali setahun
# 4                 Tangkar Sendiri                1 kali setahun
#
#   Produksi Terbanyak_Sistem Budidaya Produksi Terbanyak_Pengairan  \
# 0                                NaN                          NaN
# 1                            Organik                  Tadah Hujan
# 2                            Organik                  Tadah Hujan
# 3                            Organik                  Tadah Hujan
# 4                            Organik                  Tadah Hujan
#
#   Max_Hasil_Tangkapan_Index Tangkapan Terbanyak_Nama Area Perikanan Tangkap  \
# 0                      <NA>                                             NaN
# 1                         0                                               -
# 2                         0                                               -
# 3                         0                                               -
# 4                         0                                               -
#
#   Tangkapan Terbanyak_Jenis Ikan Tangkap  \
# 0                                    NaN
# 1                                      -
# 2                                      -
# 3                                      -
# 4                                      -
#
#   Tangkapan Terbanyak_Pemanfaatan Hasil Tangkap
# 0                                           NaN
# 1                                     Tidak ada
# 2                                     Tidak ada
# 3                                     Tidak ada
# 4                                     Tidak ada
#
# [5 rows x 55 columns]

# %%
df['Pekerjaan'] = df['Pekerjaan'].str.split(';').str[0].str.strip()
df['Sumber Pakan Ternak'] = df['Sumber Pakan Ternak'].str.split(';').str[0].str.strip()
df['Balita diperiksa di Posyandu'] = df['Balita diperiksa di Posyandu'].str.split(';').str[0].str.strip()
df['Anggota keluarga yang sering sakit'] = df['Anggota keluarga yang sering sakit'].str.split(';').str[0].str.strip()
df['Pernah dapat bantuan dari pemerintah'] = df['Pernah dapat bantuan dari pemerintah'].str.split(';').str[0].str.strip()
df['Bentuk bantuan pemerintah'] = df['Bentuk bantuan pemerintah'].str.split(';').str[0].str.strip()

# %%
df.head()
# Out:
#       ID      Desa   Nama Kepala Keluarga            Pekerjaan  \
# 0  22180    Lolong  Natalia Benga Blolong  Petani atau Nelayan
# 1  22190  Paubokol         Marianus Nurak  Petani atau Nelayan
# 2  22195  Paubokol           Viktor Gelak  Petani atau Nelayan
# 3  22200  Paubokol            Yoseph Kujo  Petani atau Nelayan
# 4  22205  Paubokol   Hendrikus Laran Ujan  Petani atau Nelayan
#
#   Pendapatan Bulanan Sumber Listrik Air Bersih Iuran BPJS Pembelian Obat  \
# 0            200000;            PLN       PDAM         0;             0;
# 1            800000;            PLN   Mata Air         0;             0;
# 2            100000;            PLN   Mata Air         0;             0;
# 3            400000;            PLN   Mata Air         0;             0;
# 4            600000;            PLN   Mata Air         0;         10000;
#
#   Pembelian Pulsa  ... Max_Produksi_Index Produksi Terbanyak_Nama Tanaman  \
# 0          20000;  ...               <NA>                             NaN
# 1         600000;  ...                  0                          Jagung
# 2              0;  ...                  0                            Padi
# 3         600000;  ...                  0                            Padi
# 4         600000;  ...                  0                            Padi
#
#   Produksi Terbanyak_Sumber Benih Produksi Terbanyak_Pola Tanam  \
# 0                             NaN                           NaN
# 1                 Tangkar Sendiri                1 kali setahun
# 2                 Tangkar Sendiri                1 kali setahun
# 3                 Tangkar Sendiri                1 kali setahun
# 4                 Tangkar Sendiri                1 kali setahun
#
#   Produksi Terbanyak_Sistem Budidaya Produksi Terbanyak_Pengairan  \
# 0                                NaN                          NaN
# 1                            Organik                  Tadah Hujan
# 2                            Organik                  Tadah Hujan
# 3                            Organik                  Tadah Hujan
# 4                            Organik                  Tadah Hujan
#
#   Max_Hasil_Tangkapan_Index Tangkapan Terbanyak_Nama Area Perikanan Tangkap  \
# 0                      <NA>                                             NaN
# 1                         0                                               -
# 2                         0                                               -
# 3                         0                                               -
# 4                         0                                               -
#
#   Tangkapan Terbanyak_Jenis Ikan Tangkap  \
# 0                                    NaN
# 1                                      -
# 2                                      -
# 3                                      -
# 4                                      -
#
#   Tangkapan Terbanyak_Pemanfaatan Hasil Tangkap
# 0                                           NaN
# 1                                     Tidak ada
# 2                                     Tidak ada
# 3                                     Tidak ada
# 4                                     Tidak ada
#
# [5 rows x 55 columns]

# %%
CATEGORIES = [
    "Rumah Tangga", 
    "Pertanian dan Perkebunan", 
    "Peternakan dan Perikanan"
]

def split_and_clean(value):
    if pd.isna(value) or not isinstance(value, str):
        return []
    
    parts = [p.strip() for p in value.split(';') if p.strip()]
    return parts

df['Sumber Limbah_Parts'] = df['Sumber Limbah'].apply(split_and_clean)
df['Pengolahan Limbah_Parts'] = df['Pengolahan Limbah'].apply(split_and_clean)

# %%
def process_limbah_data(row):
    limbah_parts = row['Sumber Limbah_Parts']
    pengolahan_parts = row['Pengolahan Limbah_Parts']
    
    output = {}
    
    for cat in CATEGORIES:
        output[f'Sumber Limbah_{cat}'] = 'no'
        output[f'Pengolahan Limbah_{cat}'] = 'nan' # Menggunakan string 'nan' sementara

    max_len = min(len(limbah_parts), len(pengolahan_parts))
    
    for i in range(max_len):
        limbah = limbah_parts[i]
        pengolahan = pengolahan_parts[i]
        
        matched_cat = None
        for cat in CATEGORIES:
            if limbah.startswith(cat):
                matched_cat = cat
                break

        if matched_cat:
            output[f'Sumber Limbah_{matched_cat}'] = 'yes'
            
            # Setel kolom Pengolahan yang sesuai
            output[f'Pengolahan Limbah_{matched_cat}'] = pengolahan
            
    return pd.Series(output)

# --- Penerapan ---

new_cols_df = df.apply(process_limbah_data, axis=1)

df = pd.concat([df, new_cols_df], axis=1)

# Opsional: Bersihkan kolom perantara
#df.drop(columns=['Limbah_Parts', 'Pengolahan_Parts'], inplace=True)

# %%
df.head()
# Out:
#       ID      Desa   Nama Kepala Keluarga            Pekerjaan  \
# 0  22180    Lolong  Natalia Benga Blolong  Petani atau Nelayan
# 1  22190  Paubokol         Marianus Nurak  Petani atau Nelayan
# 2  22195  Paubokol           Viktor Gelak  Petani atau Nelayan
# 3  22200  Paubokol            Yoseph Kujo  Petani atau Nelayan
# 4  22205  Paubokol   Hendrikus Laran Ujan  Petani atau Nelayan
#
#   Pendapatan Bulanan Sumber Listrik Air Bersih Iuran BPJS Pembelian Obat  \
# 0            200000;            PLN       PDAM         0;             0;
# 1            800000;            PLN   Mata Air         0;             0;
# 2            100000;            PLN   Mata Air         0;             0;
# 3            400000;            PLN   Mata Air         0;             0;
# 4            600000;            PLN   Mata Air         0;         10000;
#
#   Pembelian Pulsa  ... Tangkapan Terbanyak_Jenis Ikan Tangkap  \
# 0          20000;  ...                                    NaN
# 1         600000;  ...                                      -
# 2              0;  ...                                      -
# 3         600000;  ...                                      -
# 4         600000;  ...                                      -
#
#   Tangkapan Terbanyak_Pemanfaatan Hasil Tangkap Sumber Limbah_Parts  \
# 0                                           NaN      [Rumah Tangga]
# 1                                     Tidak ada      [Rumah Tangga]
# 2                                     Tidak ada      [Rumah Tangga]
# 3                                     Tidak ada         [Tidak ada]
# 4                                     Tidak ada      [Rumah Tangga]
#
#   Pengolahan Limbah_Parts Sumber Limbah_Rumah Tangga  \
# 0          [Tidak Diolah]                        yes
# 1             [Tidak ada]                        yes
# 2             [Tidak ada]                        yes
# 3             [Tidak ada]                         no
# 4             [Tidak ada]                        yes
#
#   Pengolahan Limbah_Rumah Tangga Sumber Limbah_Pertanian dan Perkebunan  \
# 0                   Tidak Diolah                                     no
# 1                      Tidak ada                                     no
# 2                      Tidak ada                                     no
# 3                            nan                                     no
# 4                      Tidak ada                                     no
#
#   Pengolahan Limbah_Pertanian dan Perkebunan  \
# 0                                        nan
# 1                                        nan
# 2                                        nan
# 3                                        nan
# 4                                        nan
#
#   Sumber Limbah_Peternakan dan Perikanan  \
# 0                                     no
# 1                                     no
# 2                                     no
# 3                                     no
# 4                                     no
#
#   Pengolahan Limbah_Peternakan dan Perikanan
# 0                                        nan
# 1                                        nan
# 2                                        nan
# 3                                        nan
# 4                                        nan
#
# [5 rows x 63 columns]

# %% [markdown]
# ### numeric

# %%
def get_max(value):
    if pd.isna(value) or not isinstance(value, str):
        return np.nan
    
    parts = value.split(';')
    numbers = []
    
    for part in parts:
        part = part.strip()
        try:
            if part: 
                numbers.append(float(part))
        except ValueError:
            continue
            
    if numbers:
        return max(numbers)
    else:
        return np.nan

#df['Memiliki Sapi'] = df['Memiliki Sapi'].apply(get_max)


df['Pendapatan Bulanan'] = df['Pendapatan Bulanan'].apply(get_max)
df['Iuran BPJS'] = df['Iuran BPJS'].apply(get_max)
df['Pembelian Obat'] = df['Pembelian Obat'].apply(get_max)
df['Pembelian Pulsa'] = df['Pembelian Pulsa'].apply(get_max)
df['Pembelian Pupuk'] = df['Pembelian Pupuk'].apply(get_max)
df['Pembelian Pestisida'] = df['Pembelian Pestisida'].apply(get_max)
df['Pembelian Benih'] = df['Pembelian Benih'].apply(get_max)
df['Upah Buruh'] = df['Upah Buruh'].apply(get_max)
df['Sewa Alat dan Mesin Pertanian'] = df['Sewa Alat dan Mesin Pertanian'].apply(get_max)
df['Memiliki Sapi'] = df['Memiliki Sapi'].apply(get_max)
df['Memiliki Kerbau'] = df['Memiliki Kerbau'].apply(get_max)
df['Memiliki Kambing'] = df['Memiliki Kambing'].apply(get_max)
df['Memiliki Ayam'] = df['Memiliki Ayam'].apply(get_max)
df['Memiliki Bebek'] = df['Memiliki Bebek'].apply(get_max)
df['Memiliki Babi'] = df['Memiliki Babi'].apply(get_max)
df['Memiliki Kuda'] = df['Memiliki Kuda'].apply(get_max)
df['Ternak dimiliki (Kg)'] = df['Ternak dimiliki (Kg)'].apply(get_max)
df['Luas Lahan Usaha m2'] = df['Luas Lahan Usaha m2'].apply(get_max)
df['Luas Lahan Rumah m2'] = df['Luas Lahan Rumah m2'].apply(get_max)
df['Luas Bangunan Rumah m2'] = df['Luas Bangunan Rumah m2'].apply(get_max)
df['Jumlah Lansia'] = df['Jumlah Lansia'].apply(get_max)

# %%
def get_sum_from_string(value):
    if pd.isna(value) or not isinstance(value, str):
        return np.nan
        
    parts = value.split(';')
    numbers = []
    
    for part in parts:
        part = part.strip()
        
        try:
            if part:
                numbers.append(float(part))
        except ValueError:
            continue
            
    if numbers:
        return sum(numbers)
    else:
        return np.nan

df['Total_Luas Lahan'] = df['Luas Lahan'].apply(get_sum_from_string)
df['Total_Produksi'] = df['Produksi'].apply(get_sum_from_string)
df['Total_Hasil Tangkapan'] = df['Hasil Tangkapan'].apply(get_sum_from_string)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 881 entries, 0 to 880
# Data columns (total 66 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   ID                                               881 non-null    object
#  1   Desa                                             881 non-null    object
#  2   Nama Kepala Keluarga                             881 non-null    object
#  3   Pekerjaan                                        870 non-null    object
#  4   Pendapatan Bulanan                               855 non-null    float64
#  5   Sumber Listrik                                   881 non-null    object
#  6   Air Bersih                                       881 non-null    object
#  7   Iuran BPJS                                       637 non-null    float64
#  8   Pembelian Obat                                   652 non-null    float64
#  9   Pembelian Pulsa                                  807 non-null    float64
#  10  Nama Tanaman                                     696 non-null    object
#  11  Sumber Benih                                     696 non-null    object
#  12  Luas Lahan                                       696 non-null    object
#  13  Produksi                                         696 non-null    object
#  14  Pola Tanam                                       696 non-null    object
#  15  Sistem Budidaya                                  696 non-null    object
#  16  Pengairan                                        696 non-null    object
#  17  Pembelian Pupuk                                  629 non-null    float64
#  18  Pembelian Pestisida                              648 non-null    float64
#  19  Pembelian Benih                                  621 non-null    float64
#  20  Upah Buruh                                       625 non-null    float64
#  21  Sewa Alat dan Mesin Pertanian                    622 non-null    float64
#  22  Memiliki Sapi                                    515 non-null    float64
#  23  Memiliki Kerbau                                  477 non-null    float64
#  24  Memiliki Kambing                                 601 non-null    float64
#  25  Memiliki Ayam                                    638 non-null    float64
#  26  Memiliki Bebek                                   492 non-null    float64
#  27  Memiliki Babi                                    607 non-null    float64
#  28  Memiliki Kuda                                    481 non-null    float64
#  29  Ternak dimiliki (Kg)                             522 non-null    float64
#  30  Sumber Pakan Ternak                              715 non-null    object
#  31  Nama Area Perikanan Tangkap                      251 non-null    object
#  32  Jenis Ikan Tangkap                               251 non-null    object
#  33  Hasil Tangkapan                                  251 non-null    object
#  34  Pemanfaatan Hasil Tangkap                        251 non-null    object
#  35  Sumber Limbah                                    788 non-null    object
#  36  Pengolahan Limbah                                788 non-null    object
#  37  Luas Lahan Usaha m2                              695 non-null    float64
#  38  Luas Lahan Rumah m2                              822 non-null    float64
#  39  Luas Bangunan Rumah m2                           823 non-null    float64
#  40  Balita diperiksa di Posyandu                     830 non-null    object
#  41  Jumlah Lansia                                    703 non-null    float64
#  42  Anggota keluarga yang sering sakit               830 non-null    object
#  43  Pernah dapat bantuan dari pemerintah             830 non-null    object
#  44  Bentuk bantuan pemerintah                        830 non-null    object
#  45  Max_Produksi_Index                               651 non-null    Int64
#  46  Produksi Terbanyak_Nama Tanaman                  649 non-null    object
#  47  Produksi Terbanyak_Sumber Benih                  651 non-null    object
#  48  Produksi Terbanyak_Pola Tanam                    651 non-null    object
#  49  Produksi Terbanyak_Sistem Budidaya               651 non-null    object
#  50  Produksi Terbanyak_Pengairan                     651 non-null    object
#  51  Max_Hasil_Tangkapan_Index                        225 non-null    Int64
#  52  Tangkapan Terbanyak_Nama Area Perikanan Tangkap  183 non-null    object
#  53  Tangkapan Terbanyak_Jenis Ikan Tangkap           175 non-null    object
#  54  Tangkapan Terbanyak_Pemanfaatan Hasil Tangkap    192 non-null    object
#  55  Sumber Limbah_Parts                              881 non-null    object
#  56  Pengolahan Limbah_Parts                          881 non-null    object
#  57  Sumber Limbah_Rumah Tangga                       881 non-null    object
#  58  Pengolahan Limbah_Rumah Tangga                   881 non-null    object
#  59  Sumber Limbah_Pertanian dan Perkebunan           881 non-null    object
#  60  Pengolahan Limbah_Pertanian dan Perkebunan       881 non-null    object
#  61  Sumber Limbah_Peternakan dan Perikanan           881 non-null    object
#  62  Pengolahan Limbah_Peternakan dan Perikanan       881 non-null    object
#  63  Total_Luas Lahan                                 673 non-null    float64
#  64  Total_Produksi                                   651 non-null    float64
#  65  Total_Hasil Tangkapan                            225 non-null    float64
# dtypes: Int64(2), float64(24), object(40)
# memory usage: 456.1+ KB

# %% [markdown]
# # Data Cleaning

# %%
for i, col in enumerate(df.columns):
    print(f"{i}. {col}")
# Out:
# 0. ID
# 1. Desa
# 2. Nama Kepala Keluarga
# 3. Pekerjaan
# 4. Pendapatan Bulanan
# 5. Sumber Listrik
# 6. Air Bersih
# 7. Iuran BPJS
# 8. Pembelian Obat
# 9. Pembelian Pulsa
# 10. Nama Tanaman
# 11. Sumber Benih
# 12. Luas Lahan
# 13. Produksi
# 14. Pola Tanam
# 15. Sistem Budidaya
# 16. Pengairan
# 17. Pembelian Pupuk
# 18. Pembelian Pestisida
# 19. Pembelian Benih
# 20. Upah Buruh
# 21. Sewa Alat dan Mesin Pertanian
# 22. Memiliki Sapi
# 23. Memiliki Kerbau
# 24. Memiliki Kambing
# 25. Memiliki Ayam
# 26. Memiliki Bebek
# 27. Memiliki Babi
# 28. Memiliki Kuda
# 29. Ternak dimiliki (Kg)
# 30. Sumber Pakan Ternak
# 31. Nama Area Perikanan Tangkap
# 32. Jenis Ikan Tangkap
# 33. Hasil Tangkapan
# 34. Pemanfaatan Hasil Tangkap
# 35. Sumber Limbah
# 36. Pengolahan Limbah
# 37. Luas Lahan Usaha m2
# 38. Luas Lahan Rumah m2
# 39. Luas Bangunan Rumah m2
# 40. Balita diperiksa di Posyandu
# 41. Jumlah Lansia
# 42. Anggota keluarga yang sering sakit
# 43. Pernah dapat bantuan dari pemerintah
# 44. Bentuk bantuan pemerintah
# 45. Max_Produksi_Index
# 46. Produksi Terbanyak_Nama Tanaman
# 47. Produksi Terbanyak_Sumber Benih
# 48. Produksi Terbanyak_Pola Tanam
# 49. Produksi Terbanyak_Sistem Budidaya
# 50. Produksi Terbanyak_Pengairan
# 51. Max_Hasil_Tangkapan_Index
# 52. Tangkapan Terbanyak_Nama Area Perikanan Tangkap
# 53. Tangkapan Terbanyak_Jenis Ikan Tangkap
# 54. Tangkapan Terbanyak_Pemanfaatan Hasil Tangkap
# 55. Sumber Limbah_Parts
# 56. Pengolahan Limbah_Parts
# 57. Sumber Limbah_Rumah Tangga
# 58. Pengolahan Limbah_Rumah Tangga
# 59. Sumber Limbah_Pertanian dan Perkebunan
# 60. Pengolahan Limbah_Pertanian dan Perkebunan
# 61. Sumber Limbah_Peternakan dan Perikanan
# 62. Pengolahan Limbah_Peternakan dan Perikanan
# 63. Total_Luas Lahan
# 64. Total_Produksi
# 65. Total_Hasil Tangkapan

# %%
df_clean = pd.concat(
    [df[['ID', 'Desa', 'Nama Kepala Keluarga', 'Pekerjaan', 'Pendapatan Bulanan', 'Sumber Listrik',
    'Air Bersih', 'Luas Lahan Usaha m2', 'Luas Lahan Rumah m2', 'Luas Bangunan Rumah m2',
         
    'Memiliki Sapi', 'Memiliki Kerbau', 'Memiliki Kambing', 'Memiliki Ayam', 'Memiliki Bebek', 
    'Memiliki Babi', 'Memiliki Kuda', 'Ternak dimiliki (Kg)', 'Sumber Pakan Ternak',
         
    'Sumber Limbah_Rumah Tangga', 'Pengolahan Limbah_Rumah Tangga', 'Sumber Limbah_Pertanian dan Perkebunan',
    'Pengolahan Limbah_Pertanian dan Perkebunan', 'Sumber Limbah_Peternakan dan Perikanan', 'Pengolahan Limbah_Peternakan dan Perikanan',

    'Produksi Terbanyak_Nama Tanaman', 'Produksi Terbanyak_Sumber Benih', 'Total_Luas Lahan', 'Total_Produksi', 
    'Produksi Terbanyak_Pola Tanam', 'Produksi Terbanyak_Sistem Budidaya', 'Produksi Terbanyak_Pengairan', 
    'Pembelian Pupuk', 'Pembelian Pestisida', 'Pembelian Benih', 'Upah Buruh', 'Sewa Alat dan Mesin Pertanian', 

    'Tangkapan Terbanyak_Nama Area Perikanan Tangkap', 'Tangkapan Terbanyak_Jenis Ikan Tangkap', 
    'Total_Hasil Tangkapan', 'Tangkapan Terbanyak_Pemanfaatan Hasil Tangkap',

    'Pembelian Pulsa', 'Iuran BPJS', 'Pembelian Obat','Balita diperiksa di Posyandu', 'Jumlah Lansia', 
    'Anggota keluarga yang sering sakit', 'Pernah dapat bantuan dari pemerintah', 'Bentuk bantuan pemerintah'
        ]]],
    axis=1
)

# %%
df_clean
# Out:
#         ID       Desa    Nama Kepala Keluarga            Pekerjaan  \
# 0    22180     Lolong   Natalia Benga Blolong  Petani atau Nelayan
# 1    22190   Paubokol          Marianus Nurak  Petani atau Nelayan
# 2    22195   Paubokol            Viktor Gelak  Petani atau Nelayan
# 3    22200   Paubokol             Yoseph Kujo  Petani atau Nelayan
# 4    22205   Paubokol    Hendrikus Laran Ujan  Petani atau Nelayan
# ..     ...        ...                     ...                  ...
# 875  24803      Mahal  Christoforus Hobamatan              lainnya
# 876  24866   Todanara         Longginus Lango  Petani atau Nelayan
# 877  24867   Todanara      Elias Ola Domaking  Petani atau Nelayan
# 879  24887  Labalimut             Petrus Asan              lainnya
# 880  24957   Todanara       Hendrikus Kewaman  Petani atau Nelayan
#
#      Pendapatan Bulanan Sumber Listrik Air Bersih  Luas Lahan Usaha m2  \
# 0              200000.0            PLN       PDAM                  0.0
# 1              800000.0            PLN   Mata Air                  0.0
# 2              100000.0            PLN   Mata Air                  0.0
# 3              400000.0            PLN   Mata Air                  0.0
# 4              600000.0            PLN   Mata Air                  0.0
# ..                  ...            ...        ...                  ...
# 875           1000000.0            PLN  Air Hujan                  0.0
# 876            500000.0            PLN     Sungai                  0.0
# 877            200000.0            PLN     Sungai                  NaN
# 879           4000000.0            PLN       PDAM                  0.0
# 880            200000.0            PLN     Sungai                  0.0
#
#      Luas Lahan Rumah m2  Luas Bangunan Rumah m2  ...  Total_Hasil Tangkapan  \
# 0                  0.114                    0.00  ...                    NaN
# 1                300.000                   48.00  ...                    0.0
# 2                750.000                   24.00  ...                    0.0
# 3               1250.000                   54.00  ...                    0.0
# 4                400.000                   30.00  ...                    0.0
# ..                   ...                     ...  ...                    ...
# 875             2500.000                   20.00  ...                    NaN
# 876              428.220                  175.33  ...                    NaN
# 877              505.850                  113.55  ...                    NaN
# 879                0.000                   80.00  ...                    NaN
# 880              417.660                  155.03  ...                    NaN
#
#      Tangkapan Terbanyak_Pemanfaatan Hasil Tangkap  Pembelian Pulsa  \
# 0                                              NaN          20000.0
# 1                                        Tidak ada         600000.0
# 2                                        Tidak ada              0.0
# 3                                        Tidak ada         600000.0
# 4                                        Tidak ada         600000.0
# ..                                             ...              ...
# 875                                            NaN              0.0
# 876                                            NaN         100000.0
# 877                                            NaN          50000.0
# 879                                            NaN          50000.0
# 880                                            NaN          20000.0
#
#      Iuran BPJS  Pembelian Obat  Balita diperiksa di Posyandu  Jumlah Lansia  \
# 0           0.0             0.0                     Tidak ada            0.0
# 1           0.0             0.0                        Sering            0.0
# 2           0.0             0.0                     Tidak ada            1.0
# 3           0.0             0.0                        Sering            0.0
# 4           0.0         10000.0                        Sering            0.0
# ..          ...             ...                           ...            ...
# 875         0.0             0.0                        Sering            0.0
# 876         0.0             0.0                        Sering            2.0
# 877         0.0             0.0                  Tidak Pernah            1.0
# 879     35000.0             0.0                     Tidak ada            2.0
# 880         0.0             0.0                     Tidak ada            2.0
#
#      Anggota keluarga yang sering sakit Pernah dapat bantuan dari pemerintah  \
# 0                                Famili                               Pernah
# 1                                  Anak                               Pernah
# 2                             Tidak ada                               Pernah
# 3                             Tidak ada                               Pernah
# 4                             Tidak ada                               Pernah
# ..                                  ...                                  ...
# 875                           Tidak ada                            Tidak ada
# 876                               Istri                               Pernah
# 877                           Tidak ada                               Pernah
# 879                               Istri                                Tidak
# 880                                Anak                            Tidak ada
#
#     Bentuk bantuan pemerintah
# 0                       Tunai
# 1                       Tunai
# 2                       Tunai
# 3                       Tunai
# 4                       Tunai
# ..                        ...
# 875                 Tidak ada
# 876                Pengobatan
# 877                     Tunai
# 879                 Tidak ada
# 880                 Tidak ada
#
# [812 rows x 49 columns]

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 812 entries, 0 to 880
# Data columns (total 49 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   ID                                               812 non-null    object
#  1   Desa                                             812 non-null    object
#  2   Nama Kepala Keluarga                             812 non-null    object
#  3   Pekerjaan                                        810 non-null    object
#  4   Pendapatan Bulanan                               797 non-null    float64
#  5   Sumber Listrik                                   812 non-null    object
#  6   Air Bersih                                       812 non-null    object
#  7   Luas Lahan Usaha m2                              685 non-null    float64
#  8   Luas Lahan Rumah m2                              812 non-null    float64
#  9   Luas Bangunan Rumah m2                           812 non-null    float64
#  10  Memiliki Sapi                                    508 non-null    float64
#  11  Memiliki Kerbau                                  473 non-null    float64
#  12  Memiliki Kambing                                 575 non-null    float64
#  13  Memiliki Ayam                                    616 non-null    float64
#  14  Memiliki Bebek                                   487 non-null    float64
#  15  Memiliki Babi                                    586 non-null    float64
#  16  Memiliki Kuda                                    477 non-null    float64
#  17  Ternak dimiliki (Kg)                             502 non-null    float64
#  18  Sumber Pakan Ternak                              674 non-null    object
#  19  Sumber Limbah_Rumah Tangga                       812 non-null    object
#  20  Pengolahan Limbah_Rumah Tangga                   812 non-null    object
#  21  Sumber Limbah_Pertanian dan Perkebunan           812 non-null    object
#  22  Pengolahan Limbah_Pertanian dan Perkebunan       812 non-null    object
#  23  Sumber Limbah_Peternakan dan Perikanan           812 non-null    object
#  24  Pengolahan Limbah_Peternakan dan Perikanan       812 non-null    object
#  25  Produksi Terbanyak_Nama Tanaman                  615 non-null    object
#  26  Produksi Terbanyak_Sumber Benih                  617 non-null    object
#  27  Total_Luas Lahan                                 638 non-null    float64
#  28  Total_Produksi                                   617 non-null    float64
#  29  Produksi Terbanyak_Pola Tanam                    617 non-null    object
#  30  Produksi Terbanyak_Sistem Budidaya               617 non-null    object
#  31  Produksi Terbanyak_Pengairan                     617 non-null    object
#  32  Pembelian Pupuk                                  616 non-null    float64
#  33  Pembelian Pestisida                              631 non-null    float64
#  34  Pembelian Benih                                  608 non-null    float64
#  35  Upah Buruh                                       612 non-null    float64
#  36  Sewa Alat dan Mesin Pertanian                    608 non-null    float64
#  37  Tangkapan Terbanyak_Nama Area Perikanan Tangkap  179 non-null    object
#  38  Tangkapan Terbanyak_Jenis Ikan Tangkap           171 non-null    object
#  39  Total_Hasil Tangkapan                            215 non-null    float64
#  40  Tangkapan Terbanyak_Pemanfaatan Hasil Tangkap    188 non-null    object
#  41  Pembelian Pulsa                                  767 non-null    float64
#  42  Iuran BPJS                                       624 non-null    float64
#  43  Pembelian Obat                                   632 non-null    float64
#  44  Balita diperiksa di Posyandu                     790 non-null    object
#  45  Jumlah Lansia                                    675 non-null    float64
#  46  Anggota keluarga yang sering sakit               790 non-null    object
#  47  Pernah dapat bantuan dari pemerintah             790 non-null    object
#  48  Bentuk bantuan pemerintah                        790 non-null    object
# dtypes: float64(24), object(25)
# memory usage: 317.2+ KB

# %%
df.isna().sum()
# Out:
# ID                                              0
# Desa                                            0
# Nama Kepala Keluarga                            0
# Pekerjaan                                      11
# Pendapatan Bulanan                             26
#                                              ...
# Sumber Limbah_Peternakan dan Perikanan          0
# Pengolahan Limbah_Peternakan dan Perikanan      0
# Total_Luas Lahan                              208
# Total_Produksi                                230
# Total_Hasil Tangkapan                         656
# Length: 66, dtype: int64

# %%
df['Luas Lahan Rumah m2'].value_counts().sort_index()
# Out:
# Luas Lahan Rumah m2
# 0.000          13
# 0.030           1
# 0.114           1
# 0.120           1
# 0.400           1
#                ..
# 10000.000       5
# 13000.000       1
# 15000.000       1
# 25000.000       1
# 1500000.000     1
# Name: count, Length: 263, dtype: int64

# %%
df['Luas Lahan Rumah m2'].value_counts().sort_values(ascending=True)
# Out:
# Luas Lahan Rumah m2
# 253.00     1
# 111.00     1
# 126.00     1
# 156.25     1
# 390.00     1
#           ..
# 200.00    23
# 150.00    32
# 300.00    36
# 400.00    39
# 625.00    86
# Name: count, Length: 263, dtype: int64

# %%
df['Luas Bangunan Rumah m2'].value_counts().sort_index()
# Out:
# Luas Bangunan Rumah m2
# 0.00        11
# 0.24         1
# 3.00         2
# 5.00         1
# 6.00         1
#             ..
# 1000.00      1
# 2500.00      1
# 3200.00      1
# 3500.00      1
# 10800.00     1
# Name: count, Length: 161, dtype: int64

# %%
df['Luas Bangunan Rumah m2'].value_counts().sort_values(ascending=True)
# Out:
# Luas Bangunan Rumah m2
# 83.00      1
# 42.11      1
# 136.36     1
# 174.46     1
# 270.00     1
#           ..
# 54.00     43
# 63.00     48
# 42.00     50
# 35.00     96
# 48.00     98
# Name: count, Length: 161, dtype: int64

# %%
df['Desa'].value_counts()
# Out:
# Desa
# Muruona         41
# Katakeja        31
# Pada            31
# Lamatuka        31
# Riangbao        30
# Waienga         30
# Tagawiti        30
# Laranwutun      30
# Watodiri        30
# Wuakerong       30
# Ile Kimok       30
# Hoelea I        30
# Puor            30
# Merdeka         30
# Kalikur         30
# Lolong          30
# Paubokol        30
# Mahal           30
# Benihading      30
# Tubungwalang    30
# Tubuk Rajan     30
# Dikesare        30
# Nubamado        30
# Labalimut       30
# Balauring       30
# Duawutun        30
# Dulitukan       30
# Todanara        29
# Bour            28
# Name: count, dtype: int64

# %%
df.dropna(subset=['Luas Bangunan Rumah m2'], inplace=True)

# %%
df['Desa'].value_counts()
# Out:
# Desa
# Muruona         38
# Pada            31
# Lamatuka        31
# Lolong          30
# Mahal           30
# Waienga         30
# Watodiri        30
# Wuakerong       30
# Ile Kimok       30
# Hoelea I        30
# Merdeka         30
# Paubokol        30
# Katakeja        30
# Benihading      30
# Labalimut       30
# Kalikur         29
# Tubungwalang    29
# Puor            29
# Nubamado        29
# Balauring       29
# Duawutun        29
# Bour            28
# Todanara        28
# Laranwutun      28
# Riangbao        27
# Dulitukan       27
# Dikesare        24
# Tagawiti        20
# Tubuk Rajan      7
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# ID                                              0
# Desa                                            0
# Nama Kepala Keluarga                            0
# Pekerjaan                                       2
# Pendapatan Bulanan                             15
#                                              ...
# Sumber Limbah_Peternakan dan Perikanan          0
# Pengolahan Limbah_Peternakan dan Perikanan      0
# Total_Luas Lahan                              177
# Total_Produksi                                198
# Total_Hasil Tangkapan                         605
# Length: 66, dtype: int64

# %%
df.dropna(subset=['Luas Lahan Rumah m2'], inplace=True)

# %%
df['Desa'].value_counts()
# Out:
# Desa
# Muruona         38
# Pada            31
# Lamatuka        31
# Lolong          30
# Mahal           30
# Waienga         30
# Watodiri        30
# Wuakerong       30
# Ile Kimok       30
# Hoelea I        30
# Merdeka         30
# Paubokol        30
# Katakeja        30
# Benihading      30
# Labalimut       30
# Kalikur         29
# Tubungwalang    29
# Nubamado        29
# Balauring       29
# Bour            28
# Todanara        28
# Puor            28
# Riangbao        27
# Dulitukan       27
# Laranwutun      26
# Duawutun        25
# Dikesare        22
# Tagawiti        19
# Tubuk Rajan      6
# Name: count, dtype: int64

# %%
df['Luas Lahan Rumah m2'].value_counts()
# Out:
# Luas Lahan Rumah m2
# 625.00    86
# 400.00    39
# 300.00    36
# 150.00    32
# 200.00    23
#           ..
# 860.00     1
# 513.00     1
# 290.00     1
# 392.00     1
# 417.66     1
# Name: count, Length: 255, dtype: int64

# %%
df['Luas Lahan Rumah m2'].value_counts().sort_index()
# Out:
# Luas Lahan Rumah m2
# 0.000          13
# 0.030           1
# 0.114           1
# 0.120           1
# 0.400           1
#                ..
# 10000.000       5
# 13000.000       1
# 15000.000       1
# 25000.000       1
# 1500000.000     1
# Name: count, Length: 255, dtype: int64

# %%
df['Luas Bangunan Rumah m2'].value_counts().sort_index()
# Out:
# Luas Bangunan Rumah m2
# 0.00        11
# 0.24         1
# 3.00         1
# 6.00         1
# 7.00         1
#             ..
# 1000.00      1
# 2500.00      1
# 3200.00      1
# 3500.00      1
# 10800.00     1
# Name: count, Length: 158, dtype: int64

# %%
df.describe(include="all").T
# Out:
#                                               count unique  \
# ID                                            812.0    NaN
# Desa                                            812     29
# Nama Kepala Keluarga                            812    807
# Pekerjaan                                       810     10
# Pendapatan Bulanan                            812.0    NaN
# Sumber Listrik                                  812      3
# Air Bersih                                      812      7
# Iuran BPJS                                    812.0    NaN
# Pembelian Obat                                812.0    NaN
# Pembelian Pulsa                               812.0    NaN
# Nama Tanaman                                    658    140
# Sumber Benih                                    658     52
# Luas Lahan                                    812.0    NaN
# Produksi                                      812.0    NaN
# Pola Tanam                                      658     28
# Sistem Budidaya                                 658     41
# Pengairan                                       658     34
# Pembelian Pupuk                               812.0    NaN
# Pembelian Pestisida                           812.0    NaN
# Pembelian Benih                               812.0    NaN
# Upah Buruh                                    812.0    NaN
# Sewa Alat dan Mesin Pertanian                 812.0    NaN
# Memiliki Sapi                                 812.0    NaN
# Memiliki Kerbau                               812.0    NaN
# Memiliki Kambing                              812.0    NaN
# Memiliki Ayam                                 812.0    NaN
# Memiliki Bebek                                812.0    NaN
# Memiliki Babi                                 812.0    NaN
# Memiliki Kuda                                 812.0    NaN
# Ternak dimiliki (Kg)                          812.0    NaN
# Sumber Pakan Ternak                             674      9
# Nama Area Perikanan Tangkap                     240     56
# Jenis Ikan Tangkap                              240     73
# Hasil Tangkapan                               812.0    NaN
# Pemanfaatan Hasil Tangkap                       240     15
# Sumber Limbah                                   757     13
# Pengolahan Limbah                               757     20
# Luas Lahan Usaha m2                           812.0    NaN
# Luas Lahan Rumah m2                           812.0    NaN
# Luas Bangunan Rumah m2                        812.0    NaN
# Apakah balita selalu diperiksa ke Posyandu?     790      8
# Jumlah Lansia                                 812.0    NaN
# Anggota keluarga yang sering sakit              790     12
# Apakah pernah dapat bantuan dari pemerintah?    790      9
# Bentuk bantuan pemerintah                       790      8
#
#                                                                top freq  \
# ID                                                             NaN  NaN
# Desa                                                       Muruona   38
# Nama Kepala Keluarga                                 Hendrikus Uma    2
# Pekerjaan                                     Petani atau Nelayan;  496
# Pendapatan Bulanan                                             NaN  NaN
# Sumber Listrik                                                 PLN  803
# Air Bersih                                                    PDAM  387
# Iuran BPJS                                                     NaN  NaN
# Pembelian Obat                                                 NaN  NaN
# Pembelian Pulsa                                                NaN  NaN
# Nama Tanaman                                               Jagung;  161
# Sumber Benih                                      Tangkar Sendiri;  219
# Luas Lahan                                                     NaN  NaN
# Produksi                                                       NaN  NaN
# Pola Tanam                                         1 kali setahun;  259
# Sistem Budidaya                                           Organik;  155
# Pengairan                                             Tadah Hujan;  248
# Pembelian Pupuk                                                NaN  NaN
# Pembelian Pestisida                                            NaN  NaN
# Pembelian Benih                                                NaN  NaN
# Upah Buruh                                                     NaN  NaN
# Sewa Alat dan Mesin Pertanian                                  NaN  NaN
# Memiliki Sapi                                                  NaN  NaN
# Memiliki Kerbau                                                NaN  NaN
# Memiliki Kambing                                               NaN  NaN
# Memiliki Ayam                                                  NaN  NaN
# Memiliki Bebek                                                 NaN  NaN
# Memiliki Babi                                                  NaN  NaN
# Memiliki Kuda                                                  NaN  NaN
# Ternak dimiliki (Kg)                                           NaN  NaN
# Sumber Pakan Ternak                                Dibuat Sendiri;  508
# Nama Area Perikanan Tangkap                                     -;   37
# Jenis Ikan Tangkap                                      Tidak ada;   36
# Hasil Tangkapan                                                NaN  NaN
# Pemanfaatan Hasil Tangkap                               Tidak ada;  130
# Sumber Limbah                                        Rumah Tangga;  459
# Pengolahan Limbah                                    Tidak Diolah;  393
# Luas Lahan Usaha m2                                            NaN  NaN
# Luas Lahan Rumah m2                                            NaN  NaN
# Luas Bangunan Rumah m2                                         NaN  NaN
# Apakah balita selalu diperiksa ke Posyandu?             Tidak ada;  510
# Jumlah Lansia                                                  NaN  NaN
# Anggota keluarga yang sering sakit                      Tidak ada;  399
# Apakah pernah dapat bantuan dari pemerintah?               Pernah;  539
# Bentuk bantuan pemerintah                                   Tunai;  291
#
#                                                         mean             std  \
# ID                                              23184.541872       688.19267
# Desa                                                     NaN             NaN
# Nama Kepala Keluarga                                     NaN             NaN
# Pekerjaan                                                NaN             NaN
# Pendapatan Bulanan                            1691038.044335  2272628.373714
# Sumber Listrik                                           NaN             NaN
# Air Bersih                                               NaN             NaN
# Iuran BPJS                                      68950.150246   491328.353553
# Pembelian Obat                                  17765.270936   140995.613965
# Pembelian Pulsa                                362482.512315    889064.17375
# Nama Tanaman                                             NaN             NaN
# Sumber Benih                                             NaN             NaN
# Luas Lahan                                         18.876009      157.534874
# Produksi                                           10.475974       75.642974
# Pola Tanam                                               NaN             NaN
# Sistem Budidaya                                          NaN             NaN
# Pengairan                                                NaN             NaN
# Pembelian Pupuk                                 38846.674877   212601.803528
# Pembelian Pestisida                             66833.560345     216604.4734
# Pembelian Benih                                  8583.745074    57748.501118
# Upah Buruh                                      57872.660099   407715.046543
# Sewa Alat dan Mesin Pertanian                   18552.955665   108937.672216
# Memiliki Sapi                                       3.003695       75.237585
# Memiliki Kerbau                                     0.008621        0.245652
# Memiliki Kambing                                    1.669951        4.370559
# Memiliki Ayam                                       5.761084        15.53984
# Memiliki Bebek                                      0.304187        2.060092
# Memiliki Babi                                       1.179803        1.873216
# Memiliki Kuda                                       0.034483        0.335037
# Ternak dimiliki (Kg)                             8579.393842   211372.406864
# Sumber Pakan Ternak                                      NaN             NaN
# Nama Area Perikanan Tangkap                              NaN             NaN
# Jenis Ikan Tangkap                                       NaN             NaN
# Hasil Tangkapan                                     1.252007        7.348417
# Pemanfaatan Hasil Tangkap                                NaN             NaN
# Sumber Limbah                                            NaN             NaN
# Pengolahan Limbah                                        NaN             NaN
# Luas Lahan Usaha m2                              63296.92326  1754604.109025
# Luas Lahan Rumah m2                              2452.078599    52640.401558
# Luas Bangunan Rumah m2                             98.297757      427.241796
# Apakah balita selalu diperiksa ke Posyandu?              NaN             NaN
# Jumlah Lansia                                       0.727833        0.847751
# Anggota keluarga yang sering sakit                       NaN             NaN
# Apakah pernah dapat bantuan dari pemerintah?             NaN             NaN
# Bentuk bantuan pemerintah                                NaN             NaN
#
#                                                   min       25%        50%  \
# ID                                            22180.0  22655.75    23007.0
# Desa                                              NaN       NaN        NaN
# Nama Kepala Keluarga                              NaN       NaN        NaN
# Pekerjaan                                         NaN       NaN        NaN
# Pendapatan Bulanan                                0.0  500000.0  1000000.0
# Sumber Listrik                                    NaN       NaN        NaN
# Air Bersih                                        NaN       NaN        NaN
# Iuran BPJS                                        0.0       0.0        0.0
# Pembelian Obat                                    0.0       0.0        0.0
# Pembelian Pulsa                                   0.0   15000.0    60000.0
# Nama Tanaman                                      NaN       NaN        NaN
# Sumber Benih                                      NaN       NaN        NaN
# Luas Lahan                                        0.0       0.0        0.5
# Produksi                                          0.0       0.0      0.132
# Pola Tanam                                        NaN       NaN        NaN
# Sistem Budidaya                                   NaN       NaN        NaN
# Pengairan                                         NaN       NaN        NaN
# Pembelian Pupuk                                   0.0       0.0        0.0
# Pembelian Pestisida                               0.0       0.0        0.0
# Pembelian Benih                                   0.0       0.0        0.0
# Upah Buruh                                        0.0       0.0        0.0
# Sewa Alat dan Mesin Pertanian                     0.0       0.0        0.0
# Memiliki Sapi                                     0.0       0.0        0.0
# Memiliki Kerbau                                   0.0       0.0        0.0
# Memiliki Kambing                                  0.0       0.0        0.0
# Memiliki Ayam                                     0.0       0.0        2.0
# Memiliki Bebek                                    0.0       0.0        0.0
# Memiliki Babi                                     0.0       0.0        0.0
# Memiliki Kuda                                     0.0       0.0        0.0
# Ternak dimiliki (Kg)                              0.0       0.0        0.0
# Sumber Pakan Ternak                               NaN       NaN        NaN
# Nama Area Perikanan Tangkap                       NaN       NaN        NaN
# Jenis Ikan Tangkap                                NaN       NaN        NaN
# Hasil Tangkapan                                   0.0       0.0        0.0
# Pemanfaatan Hasil Tangkap                         NaN       NaN        NaN
# Sumber Limbah                                     NaN       NaN        NaN
# Pengolahan Limbah                                 NaN       NaN        NaN
# Luas Lahan Usaha m2                               0.0       0.0        0.0
# Luas Lahan Rumah m2                               0.0     100.0      300.0
# Luas Bangunan Rumah m2                            0.0      35.0       48.0
# Apakah balita selalu diperiksa ke Posyandu?       NaN       NaN        NaN
# Jumlah Lansia                                     0.0       0.0        0.0
# Anggota keluarga yang sering sakit                NaN       NaN        NaN
# Apakah pernah dapat bantuan dari pemerintah?      NaN       NaN        NaN
# Bentuk bantuan pemerintah                         NaN       NaN        NaN
#
#                                                     75%         max
# ID                                             23498.25     24957.0
# Desa                                                NaN         NaN
# Nama Kepala Keluarga                                NaN         NaN
# Pekerjaan                                           NaN         NaN
# Pendapatan Bulanan                            2100000.0  36000000.0
# Sumber Listrik                                      NaN         NaN
# Air Bersih                                          NaN         NaN
# Iuran BPJS                                          0.0   9600000.0
# Pembelian Obat                                      0.0   3000000.0
# Pembelian Pulsa                                200000.0   9600000.0
# Nama Tanaman                                        NaN         NaN
# Sumber Benih                                        NaN         NaN
# Luas Lahan                                          1.0      2700.0
# Produksi                                          0.585      1050.0
# Pola Tanam                                          NaN         NaN
# Sistem Budidaya                                     NaN         NaN
# Pengairan                                           NaN         NaN
# Pembelian Pupuk                                     0.0   2880000.0
# Pembelian Pestisida                             14250.0   3240000.0
# Pembelian Benih                                     0.0    810000.0
# Upah Buruh                                          0.0   7000000.0
# Sewa Alat dan Mesin Pertanian                       0.0   1200000.0
# Memiliki Sapi                                       0.0      2144.0
# Memiliki Kerbau                                     0.0         7.0
# Memiliki Kambing                                    2.0        60.0
# Memiliki Ayam                                       7.0       350.0
# Memiliki Bebek                                      0.0        30.0
# Memiliki Babi                                       2.0        16.0
# Memiliki Kuda                                       0.0         8.0
# Ternak dimiliki (Kg)                               24.0   6000000.0
# Sumber Pakan Ternak                                 NaN         NaN
# Nama Area Perikanan Tangkap                         NaN         NaN
# Jenis Ikan Tangkap                                  NaN         NaN
# Hasil Tangkapan                                     0.0       150.0
# Pemanfaatan Hasil Tangkap                           NaN         NaN
# Sumber Limbah                                       NaN         NaN
# Pengolahan Limbah                                   NaN         NaN
# Luas Lahan Usaha m2                                51.5  50000000.0
# Luas Lahan Rumah m2                               625.0   1500000.0
# Luas Bangunan Rumah m2                            75.25     10800.0
# Apakah balita selalu diperiksa ke Posyandu?         NaN         NaN
# Jumlah Lansia                                       1.0         4.0
# Anggota keluarga yang sering sakit                  NaN         NaN
# Apakah pernah dapat bantuan dari pemerintah?        NaN         NaN
# Bentuk bantuan pemerintah                           NaN         NaN

# %%
df.isna().sum()
# Out:
# ID                                                0
# Desa                                              0
# Nama Kepala Keluarga                              0
# Pekerjaan                                         2
# Pendapatan Bulanan                               15
# Sumber Listrik                                    0
# Air Bersih                                        0
# Iuran BPJS                                      188
# Pembelian Obat                                  180
# Pembelian Pulsa                                  45
# Nama Tanaman                                    154
# Sumber Benih                                    154
# Luas Lahan                                      174
# Produksi                                        195
# Pola Tanam                                      154
# Sistem Budidaya                                 154
# Pengairan                                       154
# Pembelian Pupuk                                 196
# Pembelian Pestisida                             181
# Pembelian Benih                                 204
# Upah Buruh                                      200
# Sewa Alat dan Mesin Pertanian                   204
# Memiliki Sapi                                   304
# Memiliki Kerbau                                 339
# Memiliki Kambing                                237
# Memiliki Ayam                                   196
# Memiliki Bebek                                  325
# Memiliki Babi                                   226
# Memiliki Kuda                                   335
# Ternak dimiliki (Kg)                            310
# Sumber Pakan Ternak                             138
# Nama Area Perikanan Tangkap                     572
# Jenis Ikan Tangkap                              572
# Hasil Tangkapan                                 597
# Pemanfaatan Hasil Tangkap                       572
# Sumber Limbah                                    55
# Pengolahan Limbah                                55
# Luas Lahan Usaha m2                             127
# Luas Lahan Rumah m2                               0
# Luas Bangunan Rumah m2                            0
# Apakah balita selalu diperiksa ke Posyandu?      22
# Jumlah Lansia                                   137
# Anggota keluarga yang sering sakit               22
# Apakah pernah dapat bantuan dari pemerintah?     22
# Bentuk bantuan pemerintah                        22
# dtype: int64

# %%
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns

df[numerical_cols] = df[numerical_cols].fillna(0)

# %%
df.isna().sum()
# Out:
# ID                                                0
# Desa                                              0
# Nama Kepala Keluarga                              0
# Pekerjaan                                         2
# Pendapatan Bulanan                                0
# Sumber Listrik                                    0
# Air Bersih                                        0
# Iuran BPJS                                        0
# Pembelian Obat                                    0
# Pembelian Pulsa                                   0
# Nama Tanaman                                    154
# Sumber Benih                                    154
# Luas Lahan                                        0
# Produksi                                          0
# Pola Tanam                                      154
# Sistem Budidaya                                 154
# Pengairan                                       154
# Pembelian Pupuk                                   0
# Pembelian Pestisida                               0
# Pembelian Benih                                   0
# Upah Buruh                                        0
# Sewa Alat dan Mesin Pertanian                     0
# Memiliki Sapi                                     0
# Memiliki Kerbau                                   0
# Memiliki Kambing                                  0
# Memiliki Ayam                                     0
# Memiliki Bebek                                    0
# Memiliki Babi                                     0
# Memiliki Kuda                                     0
# Ternak dimiliki (Kg)                              0
# Sumber Pakan Ternak                             138
# Nama Area Perikanan Tangkap                     572
# Jenis Ikan Tangkap                              572
# Hasil Tangkapan                                   0
# Pemanfaatan Hasil Tangkap                       572
# Sumber Limbah                                    55
# Pengolahan Limbah                                55
# Luas Lahan Usaha m2                               0
# Luas Lahan Rumah m2                               0
# Luas Bangunan Rumah m2                            0
# Apakah balita selalu diperiksa ke Posyandu?      22
# Jumlah Lansia                                     0
# Anggota keluarga yang sering sakit               22
# Apakah pernah dapat bantuan dari pemerintah?     22
# Bentuk bantuan pemerintah                        22
# dtype: int64

# %%
df.head()
# Out:
#       ID Desa/Kelurahan   Nama Kepala Keluarga             Pekerjaan  \
# 0  22180         Lolong  Natalia Benga Blolong  Petani atau Nelayan;
# 1  22190       Paubokol         Marianus Nurak  Petani atau Nelayan;
# 2  22195       Paubokol           Viktor Gelak  Petani atau Nelayan;
# 3  22200       Paubokol            Yoseph Kujo  Petani atau Nelayan;
# 4  22205       Paubokol   Hendrikus Laran Ujan  Petani atau Nelayan;
#
#    Pendapatan Bulanan Sumber Listrik Air Bersih  Iuran BPJS  Pembelian Obat  \
# 0            200000.0            PLN       PDAM         0.0             0.0
# 1            800000.0            PLN   Mata Air         0.0             0.0
# 2            100000.0            PLN   Mata Air         0.0             0.0
# 3            400000.0            PLN   Mata Air         0.0             0.0
# 4            600000.0            PLN   Mata Air         0.0         10000.0
#
#    Pembelian Pulsa  ...  Sumber Limbah Pengolahan Limbah  Luas Lahan Usaha m2  \
# 0          20000.0  ...  Rumah Tangga;     Tidak Diolah;                  0.0
# 1         600000.0  ...  Rumah Tangga;        Tidak ada;                  0.0
# 2              0.0  ...  Rumah Tangga;        Tidak ada;                  0.0
# 3         600000.0  ...     Tidak ada;        Tidak ada;                  0.0
# 4         600000.0  ...  Rumah Tangga;        Tidak ada;                  0.0
#
#    Luas Lahan Rumah m2 Luas Bangunan Rumah m2  \
# 0                  NaN                    0.0
# 1                300.0                   48.0
# 2                750.0                   24.0
# 3               1250.0                   54.0
# 4                400.0                   30.0
#
#   Apakah balita selalu diperiksa ke Posyandu? Jumlah Lansia  \
# 0                                  Tidak ada;           0.0
# 1                                     Sering;           0.0
# 2                                  Tidak ada;           1.0
# 3                                     Sering;           0.0
# 4                                     Sering;           0.0
#
#    Anggota keluarga yang sering sakit  \
# 0                             Famili;
# 1                               Anak;
# 2                          Tidak ada;
# 3                          Tidak ada;
# 4                          Tidak ada;
#
#    Apakah pernah dapat bantuan dari pemerintah?  Bentuk bantuan pemerintah
# 0                                       Pernah;                     Tunai;
# 1                                       Pernah;                     Tunai;
# 2                                       Pernah;                     Tunai;
# 3                                       Pernah;                     Tunai;
# 4                                       Pernah;                     Tunai;
#
# [5 rows x 45 columns]

# %% [markdown]
# ## categoric

# %%
df['Produksi'].value_counts()
# Out:
# Produksi
# 0.0       65
# 1.0       41
# 2.0       11
# 3.0        9
# 50.0       8
# 6.0        4
# 200.0      4
# 4.0        3
# 40.0       2
# 5.0        2
# 100.0      2
# 300.0      2
# 60.0       2
# 350.0      1
# 32.0       1
# 150.0      1
# 18.0       1
# 600.0      1
# 315.0      1
# 151.0      1
# 20.0       1
# 160.0      1
# 700.0      1
# 12.0       1
# 80.0       1
# 900.0      1
# 8.0        1
# 190.0      1
# 10.0       1
# 500.0      1
# 1000.0     1
# 204.0      1
# 22.0       1
# 400.0      1
# 1050.0     1
# Name: count, dtype: int64

# %%
df['Pekerjaan'].value_counts()
# Out:
# Pekerjaan
# Petani atau Nelayan;                         534
# lainnya;                                      91
# Wiraswasta;                                   75
# PNS;                                          60
# Karyawan Swasta;                              39
# Tidak ada;                                    33
# Buruh Tani;                                   33
# Petani atau Nelayan; Petani atau Nelayan;      2
# Wiraswasta; lainnya; Tidak ada;                1
# lainnya; Petani atau Nelayan;                  1
# Petani atau Nelayan; lainnya;                  1
# Name: count, dtype: int64

# %%
df['Sumber Listrik'].value_counts()
# Out:
# Sumber Listrik
# PLN          871
# Tidak ada      5
# Bukan PLN      5
# Name: count, dtype: int64

# %%
df['Air Bersih'].value_counts()
# Out:
# Air Bersih
# PDAM          430
# Sumur Bor     143
# Mata Air      112
# Sungai         66
# Air Hujan      64
# Sumur Gali     61
# Air Galon       5
# Name: count, dtype: int64

# %%
df['Iuran BPJS'].value_counts()
# Out:
# Iuran BPJS
# 0.0          519
# 35000.0       14
# 420000.0       9
# 150000.0       6
# 100000.0       6
# 25000.0        6
# 10000.0        4
# 120000.0       3
# 50000.0        3
# 60000.0        3
# 140000.0       3
# 1800000.0      3
# 15000.0        2
# 80000.0        2
# 3000000.0      2
# 210000.0       2
# 240000.0       2
# 720000.0       2
# 360000.0       2
# 20000.0        2
# 105000.0       2
# 70000.0        2
# 300000.0       2
# 42000.0        2
# 600000.0       1
# 1260000.0      1
# 175000.0       1
# 18000.0        1
# 27000.0        1
# 34000.0        1
# 2100000.0      1
# 450000.0       1
# 200000.0       1
# 75000.0        1
# 4800000.0      1
# 85000.0        1
# 2000.0         1
# 16800.0        1
# 6000000.0      1
# 30000.0        1
# 9600000.0      1
# 37000.0        1
# 660000.0       1
# 1680000.0      1
# 2160000.0      1
# 1200000.0      1
# 63000.0        1
# 40000.0        1
# 900000.0       1
# 145000.0       1
# 125000.0       1
# 250000.0       1
# 288000.0       1
# 25500.0        1
# 38500.0        1
# 20222.0        1
# 16500.0        1
# 272000.0       1
# Name: count, dtype: int64

# %%
df['Obat'].value_counts()
# Out:
# Obat
# 0.0          510
# 10000.0       34
# 100000.0      13
# 20000.0       12
# 50000.0       10
# 5000.0         8
# 120000.0       8
# 25000.0        8
# 30000.0        7
# 15000.0        6
# 200000.0       5
# 240000.0       4
# 150000.0       4
# 60000.0        3
# 75000.0        2
# 250000.0       2
# 12000.0        1
# 96000.0        1
# 160000.0       1
# 80000.0        1
# 1200000.0      1
# 2000000.0      1
# 51000.0        1
# 600000.0       1
# 5900.0         1
# 3000000.0      1
# 4000.0         1
# 216000.0       1
# 1000000.0      1
# 40000.0        1
# 72000.0        1
# 13500.0        1
# Name: count, dtype: int64

# %%
df['Pulsa Ponsel'].value_counts()
# Out:
# Pulsa Ponsel
# 0.0          139
# 50000.0      104
# 100000.0      95
# 600000.0      37
# 20000.0       31
#             ...
# 2040000.0      1
# 400000.0       1
# 816000.0       1
# 1980000.0      1
# 23000.0        1
# Name: count, Length: 107, dtype: int64

# %%
df['Pupuk'].value_counts()
# Out:
# Pupuk
# 0;               509
# ;                232
# 150000;           30
# 50000;            11
# 300000;            5
# 11000;             5
# 12500;             4
# 1800000;           3
# 70000;             3
# 25000;             3
# 1500000;           3
# 0; 0;              3
# 75000;             3
# 15000;             2
# ; ;                2
# 600000;            2
# 1200000;           2
# 250000;            2
# 500000;            2
# 0; ;               2
# 22000;             1
# 112500;            1
# 37500;             1
# 80000;             1
# 13000;             1
# 28000;             1
# 260000;            1
# 62500;             1
# 34000;             1
# 140000;            1
# 105000;            1
# 11250;             1
# 16500;             1
# 16750; 16750;      1
# 112000;            1
# 2550000;           1
# 340000;            1
# ; ; ;              1
# 35000;             1
# 2880000;           1
# 150000; ;          1
# ; 0;               1
# 30000;             1
# 20000;             1
# 120000;            1
# 40000;             1
# 200000;            1
# 100000;            1
# 60000;             1
# 135000;            1
# 750000;            1
# 67500;             1
# 130000;            1
# 17000;             1
# 275000;            1
# 420000;            1
# Name: count, dtype: int64

# %%
df['Pestisida/Herbisida/Fungisida'].value_counts()
# Out:
# Pestisida/Herbisida/Fungisida
# 0.0          425
# 120000.0      19
# 100000.0      14
# 80000.0       14
# 90000.0        8
#             ...
# 6250.0         1
# 2160000.0      1
# 475000.0       1
# 17000.0        1
# 45000.0        1
# Name: count, Length: 75, dtype: int64

# %%
df['Benih'].value_counts()
# Out:
# Benih
# 0.0         568
# 50000.0       8
# 20000.0       5
# 10000.0       3
# 15000.0       3
# 100000.0      3
# 120000.0      2
# 300000.0      2
# 200000.0      2
# 85000.0       2
# 90000.0       2
# 750000.0      1
# 175000.0      1
# 540000.0      1
# 12500.0       1
# 180000.0      1
# 45000.0       1
# 60000.0       1
# 5000.0        1
# 25000.0       1
# 240000.0      1
# 70000.0       1
# 450000.0      1
# 425000.0      1
# 600000.0      1
# 810000.0      1
# 16000.0       1
# 30000.0       1
# 7000.0        1
# 12000.0       1
# 75000.0       1
# Name: count, dtype: int64

# %%
df['Upah Buruh'].value_counts()
# Out:
# Upah Buruh
# 0.0          547
# 150000.0       8
# 200000.0       7
# 50000.0        6
# 100000.0       6
# 250000.0       6
# 500000.0       6
# 1500000.0      4
# 1000000.0      4
# 75000.0        4
# 600000.0       3
# 300000.0       3
# 7000000.0      2
# 750000.0       2
# 360000.0       1
# 100.0          1
# 720000.0       1
# 375000.0       1
# 2540000.0      1
# 240000.0       1
# 37500.0        1
# 1400000.0      1
# 400000.0       1
# 15000.0        1
# 1750000.0      1
# 2000000.0      1
# 80000.0        1
# 20000.0        1
# 2725000.0      1
# 520000.0       1
# 60000.0        1
# Name: count, dtype: int64

# %%
df['Sewa Alat dan Mesin Pertanian'].value_counts()
# Out:
# Sewa Alat dan Mesin Pertanian
# 0.0          575
# 100000.0       9
# 150000.0       5
# 1000000.0      4
# 400000.0       3
# 500000.0       3
# 40000.0        3
# 20000.0        2
# 125000.0       2
# 600000.0       2
# 250000.0       2
# 80000.0        1
# 800000.0       1
# 45000.0        1
# 480000.0       1
# 200000.0       1
# 120000.0       1
# 900000.0       1
# 58000.0        1
# 50000.0        1
# 1200000.0      1
# 580000.0       1
# 300000.0       1
# Name: count, dtype: int64

# %%
df['Sapi'].value_counts()
# Out:
# Sapi
# 0.0       409
# 1.0        33
# 2.0        24
# 3.0        20
# 5.0        10
# 4.0         7
# 6.0         4
# 7.0         3
# 8.0         1
# 2144.0      1
# 9.0         1
# 14.0        1
# 12.0        1
# Name: count, dtype: int64

# %%
df['Kambing'].value_counts()
# Out:
# Kambing
# 0.0     290
# 2.0      69
# 1.0      62
# 3.0      54
# 4.0      36
# 5.0      24
# 10.0     15
# 8.0      10
# 6.0       9
# 7.0       8
# 20.0      6
# 12.0      4
# 15.0      3
# 40.0      2
# 30.0      1
# 50.0      1
# 19.0      1
# 11.0      1
# 60.0      1
# 23.0      1
# 9.0       1
# 14.0      1
# 13.0      1
# Name: count, dtype: int64

# %%
# ubah string kosong menjadi NaN
df['Iuran BPJS'] = df['Iuran BPJS'].str.strip().replace('', np.nan)
df['Obat'] = df['Obat'].str.strip().replace('', np.nan)
df['Pulsa Ponsel'] = df['Pulsa Ponsel'].str.strip().replace('', np.nan)
df['Pupuk'] = df['Pupuk'].str.strip().replace('', np.nan)
df['Pestisida/Herbisida/Fungisida'] = df['Pestisida/Herbisida/Fungisida'].str.strip().replace('', np.nan)
df['Benih'] = df['Benih'].str.strip().replace('', np.nan)
df['Upah Buruh'] = df['Upah Buruh'].str.strip().replace('', np.nan)
df['Sewa Alat dan Mesin Pertanian'] = df['Sewa Alat dan Mesin Pertanian'].str.strip().replace('', np.nan)

# %%
df.isna().sum()
# Out:
# ID                                                0
# Desa/Kelurahan                                    0
# Nama Kepala Keluarga                              0
# Pekerjaan                                        11
# Pendapatan Bulanan (Rp.)                         28
# Sumber Listrik                                    0
# Air Bersih                                        0
# Iuran BPJS                                      244
# Obat                                            229
# Pulsa Ponsel                                     74
# Nama Tanaman                                    185
# Sumber Benih                                    185
# Luas Lahan                                      185
# Produktivitas                                   185
# Pola Tanam                                      185
# Sistem Budidaya                                 185
# Pengairan                                       185
# Pupuk                                            17
# Pestisida/Herbisida/Fungisida                   234
# Benih                                           261
# Upah Buruh                                      256
# Sewa Alat dan Mesin Pertanian                   259
# Sapi                                            366
# Kerbau                                          166
# Kambing                                         280
# Ayam.3                                          166
# Bebek                                           166
# Babi                                            166
# Kuda                                            166
# Jumlah Hasil (Kg)                               166
# Sumber Pakan                                    166
# Nama Area Tangkap                               630
# Jenis Ikan.1                                    630
# Jumlah Hasil                                    630
# Pemanfaatan Hasil Tangkap                       630
# Sumber Limbah                                    93
# Pengolahan                                       93
# Luas Lahan Usaha m2                              46
# Luas Lahan Rumah m2                              46
# Luas Bangunan Rumah m2                           46
# Apakah balita selalu diperiksa ke Posyandu?      51
# Jumlah Lansia                                    51
# Anggota keluarga yang sering sakit               51
# Apakah pernah dapat bantuan dari pemerintah?     51
# Kalau iya, apa bentuk bantuan tersebut?          51
# dtype: int64

# %%
df['Iuran BPJS'].isna().sum()
# Out:
# 246

# %%
df['Pekerjaan'] = df['Pekerjaan'].str.split(';').str[0].str.strip()

# %%
saling berkaitan

df['Nama Tanaman'].value_counts()
df['Sumber Benih'].value_counts()
df['Luas Lahan'].value_counts()
df['Produktivitas'].value_counts()
df['Pola Tanam'].value_counts()
df['Sistem Budidaya'].value_counts()
df['Pengairan'].value_counts()

# %% [markdown]
# # Numerin & Categoric

# %%
# daftar kolom numerik
num_cols = [
    "Pendapatan Bulanan (Rp.)", "Iuran BPJS", "Obat", "Pulsa Ponsel", 
    "Luas Lahan", "Produktivitas", "Pengairan", "Pupuk",
    "Pestisida/Herbisida/Fungisida", "Benih", "Upah Buruh",
    "Sewa Alat dan Mesin Pertanian", "Sapi", "Kerbau", "Kambing",
    "Ayam.3", "Bebek", "Babi", "Kuda", "Jumlah Hasil (Kg)", 
    "Jumlah Hasil", "Luas Lahan Usaha m2", "Luas Lahan Rumah m2",
    "Luas Bangunan Rumah m2", "Jumlah Lansia"
]

# konversi pakai pd.to_numeric biar aman
for col in num_cols:
    df[col] = pd.to_numeric(df[col].astype(str).str.replace(",", ".").str.replace(r"[^0-9\.-]", "", regex=True), errors="coerce")

# cek hasil
print(df[num_cols].dtypes)
# Out:
# Pendapatan Bulanan (Rp.)         float64
# Iuran BPJS                       float64
# Obat                             float64
# Pulsa Ponsel                     float64
# Luas Lahan                       float64
# Produktivitas                    float64
# Pengairan                        float64
# Pupuk                            float64
# Pestisida/Herbisida/Fungisida    float64
# Benih                            float64
# Upah Buruh                       float64
# Sewa Alat dan Mesin Pertanian    float64
# Sapi                             float64
# Kerbau                           float64
# Kambing                          float64
# Ayam.3                           float64
# Bebek                            float64
# Babi                             float64
# Kuda                             float64
# Jumlah Hasil (Kg)                float64
# Jumlah Hasil                     float64
# Luas Lahan Usaha m2              float64
# Luas Lahan Rumah m2              float64
# Luas Bangunan Rumah m2           float64
# Jumlah Lansia                    float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 881 entries, 0 to 880
# Data columns (total 45 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   ID                                            881 non-null    int64
#  1   Desa/Kelurahan                                881 non-null    object
#  2   Nama Kepala Keluarga                          881 non-null    object
#  3   Pekerjaan                                     881 non-null    object
#  4   Pendapatan Bulanan (Rp.)                      855 non-null    float64
#  5   Sumber Listrik                                881 non-null    object
#  6   Air Bersih                                    881 non-null    object
#  7   Iuran BPJS                                    637 non-null    float64
#  8   Obat                                          652 non-null    float64
#  9   Pulsa Ponsel                                  807 non-null    float64
#  10  Nama Tanaman                                  881 non-null    object
#  11  Sumber Benih                                  881 non-null    object
#  12  Luas Lahan                                    486 non-null    float64
#  13  Produktivitas                                 443 non-null    float64
#  14  Pola Tanam                                    881 non-null    object
#  15  Sistem Budidaya                               881 non-null    object
#  16  Pengairan                                     0 non-null      float64
#  17  Pupuk                                         629 non-null    float64
#  18  Pestisida/Herbisida/Fungisida                 648 non-null    float64
#  19  Benih                                         621 non-null    float64
#  20  Upah Buruh                                    625 non-null    float64
#  21  Sewa Alat dan Mesin Pertanian                 622 non-null    float64
#  22  Sapi                                          515 non-null    float64
#  23  Kerbau                                        477 non-null    float64
#  24  Kambing                                       601 non-null    float64
#  25  Ayam.3                                        638 non-null    float64
#  26  Bebek                                         492 non-null    float64
#  27  Babi                                          607 non-null    float64
#  28  Kuda                                          481 non-null    float64
#  29  Jumlah Hasil (Kg)                             522 non-null    float64
#  30  Sumber Pakan                                  881 non-null    object
#  31  Nama Area Tangkap                             881 non-null    object
#  32  Jenis Ikan.1                                  881 non-null    object
#  33  Jumlah Hasil                                  225 non-null    float64
#  34  Pemanfaatan Hasil Tangkap                     881 non-null    object
#  35  Sumber Limbah                                 881 non-null    object
#  36  Pengolahan                                    881 non-null    object
#  37  Luas Lahan Usaha m2                           695 non-null    float64
#  38  Luas Lahan Rumah m2                           822 non-null    float64
#  39  Luas Bangunan Rumah m2                        823 non-null    float64
#  40  Apakah balita selalu diperiksa ke Posyandu?   881 non-null    object
#  41  Jumlah Lansia                                 703 non-null    float64
#  42  Anggota keluarga yang sering sakit            881 non-null    object
#  43  Apakah pernah dapat bantuan dari pemerintah?  881 non-null    object
#  44  Kalau iya, apa bentuk bantuan tersebut?       881 non-null    object
# dtypes: float64(25), int64(1), object(19)
# memory usage: 309.9+ KB

# %%
df.isna().sum()
# Out:
# ID                                                0
# Desa/Kelurahan                                    0
# Nama Kepala Keluarga                              0
# Pekerjaan                                         0
# Pendapatan Bulanan (Rp.)                         26
# Sumber Listrik                                    0
# Air Bersih                                        0
# Iuran BPJS                                      244
# Obat                                            229
# Pulsa Ponsel                                     74
# Nama Tanaman                                      0
# Sumber Benih                                      0
# Luas Lahan                                      395
# Produktivitas                                   438
# Pola Tanam                                        0
# Sistem Budidaya                                   0
# Pengairan                                       881
# Pupuk                                           252
# Pestisida/Herbisida/Fungisida                   233
# Benih                                           260
# Upah Buruh                                      256
# Sewa Alat dan Mesin Pertanian                   259
# Sapi                                            366
# Kerbau                                          404
# Kambing                                         280
# Ayam.3                                          243
# Bebek                                           389
# Babi                                            274
# Kuda                                            400
# Jumlah Hasil (Kg)                               359
# Sumber Pakan                                      0
# Nama Area Tangkap                                 0
# Jenis Ikan.1                                      0
# Jumlah Hasil                                    656
# Pemanfaatan Hasil Tangkap                         0
# Sumber Limbah                                     0
# Pengolahan                                        0
# Luas Lahan Usaha m2                             186
# Luas Lahan Rumah m2                              59
# Luas Bangunan Rumah m2                           58
# Apakah balita selalu diperiksa ke Posyandu?       0
# Jumlah Lansia                                   178
# Anggota keluarga yang sering sakit                0
# Apakah pernah dapat bantuan dari pemerintah?      0
# Kalau iya, apa bentuk bantuan tersebut?           0
# dtype: int64

# %%
import numpy as np
import pandas as pd
import re

_num_pattern = re.compile(r'^\s*[+-]?\d+(?:[.,]\d+)?\s*$')  # dukung koma/titik desimal

def sum_semicolon_numbers(cell):
    # NaN -> NaN
    if pd.isna(cell):
        return np.nan

    s = str(cell).strip()
    if s == '':
        return np.nan  # sel benar-benar kosong

    # Normalisasi delimiter & desimal
    s = s.replace('；', ';')           # fullwidth semicolon -> normal
    parts = [p.strip() for p in s.split(';')]

    total = 0.0
    found_number = False
    for p in parts:
        if p == '':         # kosong di antara ; -> 0 (skip saja)
            continue
        p2 = p.replace(',', '.')  # dukung "0,5"
        if _num_pattern.match(p2):
            total += float(p2)
            found_number = True
        else:
            # token tidak numerik -> abaikan (anggap 0)
            # kalau mau anggap invalid -> set found_number=False dan break lalu return np.nan
            pass

    return total if found_number else np.nan

# %%
for col in num_cols:
    df[col] = df[col].apply(sum_semicolon_numbers)

# pastikan hasilnya numeric
df[num_cols] = df[num_cols].apply(pd.to_numeric, errors="coerce")

# %%
#df[num_cols].head()

# %%
df.isna().sum()
# Out:
# ID                                                0
# Desa/Kelurahan                                    0
# Nama Kepala Keluarga                              0
# Pekerjaan                                         0
# Pendapatan Bulanan (Rp.)                         26
# Sumber Listrik                                    0
# Air Bersih                                        0
# Iuran BPJS                                      244
# Obat                                            229
# Pulsa Ponsel                                     74
# Nama Tanaman                                      0
# Sumber Benih                                      0
# Luas Lahan                                      395
# Produktivitas                                   438
# Pola Tanam                                        0
# Sistem Budidaya                                   0
# Pengairan                                       881
# Pupuk                                           252
# Pestisida/Herbisida/Fungisida                   233
# Benih                                           260
# Upah Buruh                                      256
# Sewa Alat dan Mesin Pertanian                   259
# Sapi                                            366
# Kerbau                                          404
# Kambing                                         280
# Ayam.3                                          243
# Bebek                                           389
# Babi                                            274
# Kuda                                            400
# Jumlah Hasil (Kg)                               359
# Sumber Pakan                                      0
# Nama Area Tangkap                                 0
# Jenis Ikan.1                                      0
# Jumlah Hasil                                    656
# Pemanfaatan Hasil Tangkap                         0
# Sumber Limbah                                     0
# Pengolahan                                        0
# Luas Lahan Usaha m2                             186
# Luas Lahan Rumah m2                              59
# Luas Bangunan Rumah m2                           58
# Apakah balita selalu diperiksa ke Posyandu?       0
# Jumlah Lansia                                   178
# Anggota keluarga yang sering sakit                0
# Apakah pernah dapat bantuan dari pemerintah?      0
# Kalau iya, apa bentuk bantuan tersebut?           0
# dtype: int64

# %% [markdown]
# ## Menangani missing value

# %%
df[num_cols] = df[num_cols].fillna(0)

# %% [markdown]
# catatan :
#
# untuk penanganan mmsising value "numerik" bisa diatasi dengan imputasi nilai sentral (median, modus), spesifik, ataupun advance. tetapi hal ini harus didasari **background knowledge** yang benar.
#
# dalam kasus ini, tergantung hasil akhir apa yang diinginkan? apakah persenan orang yang memiliki kuda, misalnya. kalau seperti itu, maka imputasi dengan nilai 0 (fillna) adalah yang terbaik.
#
# untuk sementara, missing value data numerik kita ubah menjadi 0.
#
#
# > Menggunakan 0 sebagai imputasi bisa menimbulkan bias atau distorsi jika:
#
# >Nilai 0 Bukan Representasi Realitas: Jika nilai yang hilang seharusnya adalah nilai positif/negatif yang signifikan (misalnya rata-rata gaji), menggantinya dengan 0 akan menarik rata-rata kolom ke bawah dan mengubah distribusi data secara drastis, menyebabkan model prediksi Anda menjadi bias.

# %%
df['Desa/Kelurahan'].value_counts()
# Out:
# Desa/Kelurahan
# Muruona         41
# Katakeja        31
# Pada            31
# Lamatuka        31
# Riangbao        30
# Waienga         30
# Tagawiti        30
# Laranwutun      30
# Watodiri        30
# Wuakerong       30
# Ile Kimok       30
# Hoelea I        30
# Puor            30
# Merdeka         30
# Kalikur         30
# Lolong          30
# Paubokol        30
# Mahal           30
# Benihading      30
# Tubungwalang    30
# Tubuk Rajan     30
# Dikesare        30
# Nubamado        30
# Labalimut       30
# Balauring       30
# Duawutun        30
# Dulitukan       30
# Todanara        29
# Bour            28
# Name: count, dtype: int64

# %%
df['Desa/Kelurahan'] = df['Desa/Kelurahan'].str.replace(r'\bPADA\b', 'Pada', regex=True)

# %%
df.to_csv("data_cleaned.csv", index=False)
